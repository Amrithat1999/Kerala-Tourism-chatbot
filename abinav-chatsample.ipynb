# %%
import nltk

# %%
import re
import os
import csv
from nltk.stem.snowball import SnowballStemmer
import random
from nltk.classify import SklearnClassifier
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import numpy as np
import pandas as pd

# %%
#get multiple ouputs in the same line
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

#ignore all warnings
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %%
#display all rows and cols of a dataframe intead of a truncated version
from IPython.display import display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Preprocess

sentence = "The computer was born to solve problems that did not exist before"
sentence2 = "Most of the good programmers do programming not because they expect to get paid or get adulation by the public, but because it is fun to program."

# %%
#convert sentence to lower case

'This' == 'this'
print('AbcdEFgH'.lower())
sentence.lower()
sentence2.lower()
# Out:
# False
# abcdefgh
# 'the computer was born to solve problems that did not exist before'
# 'most of the good programmers do programming not because they expect to get paid or get adulation by the public, but because it is fun to program.'

# %%
#tokenize and extrax=ction of individual features

tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(sentence)
tokens
tokens2 = tokenizer.tokenize(sentence2)
tokens2
# Out:
# ['The',
#  'computer',
#  'was',
#  'born',
#  'to',
#  'solve',
#  'problems',
#  'that',
#  'did',
#  'not',
#  'exist',
#  'before']
# ['Most',
#  'of',
#  'the',
#  'good',
#  'programmers',
#  'do',
#  'programming',
#  'not',
#  'because',
#  'they',
#  'expect',
#  'to',
#  'get',
#  'paid',
#  'or',
#  'get',
#  'adulation',
#  'by',
#  'the',
#  'public',
#  'but',
#  'because',
#  'it',
#  'is',
#  'fun',
#  'to',
#  'program']

# %%
#Stopwords : Filter words to remove non useful words
filtered_words = [w for w in tokens if not w in stopwords.words('english')]
filtered_words
# Out:
# ['The', 'computer', 'born', 'solve', 'problems', 'exist']

# %%
filtered_words = [w for w in tokens2 if not w in stopwords.words('english')]
filtered_words
# Out:
# ['Most',
#  'good',
#  'programmers',
#  'programming',
#  'expect',
#  'get',
#  'paid',
#  'get',
#  'adulation',
#  'public',
#  'fun',
#  'program']

# %%
def preprocess(sentence):
    sentence = sentence.lower()
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(sentence)
    filtered_words = [w for w in tokens if not w in stopwords.words('english')]
    return filtered_words

# %%
preprocessed_sentence = preprocess(sentence)
print(preprocessed_sentence)
# Out:
# ['computer', 'born', 'solve', 'problems', 'exist']

# %%
preprocess(sentence2)
# Out:
# ['good',
#  'programmers',
#  'programming',
#  'expect',
#  'get',
#  'paid',
#  'get',
#  'adulation',
#  'public',
#  'fun',
#  'program']

# %%
#tagging

tags = nltk.pos_tag(preprocess(sentence))
print(tags)
# Out:
# [('computer', 'NN'), ('born', 'VBN'), ('solve', 'VB'), ('problems', 'NNS'), ('exist', 'VBP')]

# %%
tags = nltk.pos_tag(preprocess(sentence2))
print(tags)
# Out:
# [('good', 'JJ'), ('programmers', 'NNS'), ('programming', 'VBG'), ('expect', 'VBP'), ('get', 'NN'), ('paid', 'VBN'), ('get', 'VB'), ('adulation', 'JJ'), ('public', 'JJ'), ('fun', 'NN'), ('program', 'NN')]

# %%
#extracting only nouns and verbs
def extract_tagged(sentence):
    features = []
    for tagged_word in sentence:
        word, tag= tagged_word
        if tag=='NN' or tag=='VBN' or tag=='NNS' or tag=='VBP' or tag=='RB' or tag=='VBZ' or tag=='VBG' or tag=='PRP' or tag=='JJ':
            features.append(word)
    return features

# %%
extract_tagged(tags)
# Out:
# ['good',
#  'programmers',
#  'programming',
#  'expect',
#  'get',
#  'paid',
#  'adulation',
#  'public',
#  'fun',
#  'program']

# %%
#lemmatize word
lmtzr = WordNetLemmatizer()
print(lmtzr.lemmatize('feet'))
print(lmtzr.lemmatize('giving'))
# Out:
# foot
# giving

# %%
#stem words
words_for_stemming = ['stem', 'stemming', 'stemmed', 'stemmer', 'stems', 'feet', 'willing']

# %%
stemmer = SnowballStemmer('english')
[stemmer.stem(x) for x in words_for_stemming]
# Out:
# ['stem', 'stem', 'stem', 'stemmer', 'stem', 'feet', 'will']

# %%
#putting it all together
def extract_features(text):
    words = preprocess(text)
    tags = nltk.pos_tag(words)
    extracted_features = extract_tagged(tags)
    stemmed_words = [stemmer.stem(x) for x in extracted_features]
    result = [lmtzr.lemmatize(x) for x in stemmed_words]
    return result

# %%
sentence
# Out:
# 'The computer was born to solve problems that did not exist before'

# %%
words = extract_features(sentence)
words
# Out:
# ['comput', 'born', 'problem', 'exist']

# %%
sentence2
# Out:
# 'Most of the good programmers do programming not because they expect to get paid or get adulation by the public, but because it is fun to program.'

# %%
words = extract_features(sentence2)
words
# Out:
# ['good',
#  'programm',
#  'program',
#  'expect',
#  'get',
#  'paid',
#  'adul',
#  'public',
#  'fun',
#  'program']

# %%
extract_features('Everybody should learn to program a computer, because it teaches you how to think')
# Out:
# ['everybodi', 'learn', 'program', 'comput', 'teach', 'think']

# %%
#implementing bag of words
def word_feats(words):
    return dict([(word, True) for word in words])

# %%
word_feats(words)
# Out:
# {'good': True,
#  'programm': True,
#  'program': True,
#  'expect': True,
#  'get': True,
#  'paid': True,
#  'adul': True,
#  'public': True,
#  'fun': True}

# %%
#parsing the whole document
def extract_feature_from_doc(data):
    result =[]
    corpus =[]
    #the responses of chatboat
    answers={}
    for (text,category,answer) in data:
        features = extract_features(text)
        corpus.append(features)
        result.append((word_feats(features), category))
        answers[category]= answer
    return (result, sum(corpus,[]), answers)

# %%
extract_feature_from_doc([['This is the input text from user', 'category', 'answer to give']])
# Out:
# ([({'input': True, 'user': True}, 'category')],
#  ['input', 'user'],
#  {'category': 'answer to give'})

# %%
def get_content(filename):
    doc = os.path.join(filename)
    with open(doc,'r') as content_file:
        lines = csv.reader(content_file,delimiter='|')
        data = [x for x in lines if len(x) ==3]
        return data

# %%
filename= 'D:/MaiTexa/projects/AI_ChatBot_Python-master/kerala tourism sample data.txt'
data = get_content(filename)
data
# Out:
# [['Hello',
#   'Greetings',
#   'Hello. I am ABHIbot. I will serve your leave enquiries.'],
#  ['hi hello',
#   'Greetings',
#   'Hello. I am ABHIbot. I will serve your leave enquiries.'],
#  ['hi ',
#   'Greetings',
#   'Hello. I am ABHIbot. I will serve your leave enquiries.'],
#  ['hi',
#   'Greetings',
#   'Hello. I am ABHIbot. I will serve your leave enquiries.'],
#  ['hi',
#   'Greetings',
#   'Hello. I am ABHIbot. I will serve your leave enquiries.'],
#  ['hey',
#   'Greetings',
#   'Hello. I am ABHIbot. I will serve your leave enquiries.'],
#  ['hello, hi',
#   'Greetings',
#   'Hello. I am ABHIbot. I will serve your leave enquiries.'],
#  ['hey',
#   'Greetings',
#   'Hello. I am ABHIbot. I will serve your leave enquiries.'],
#  ['hey, hi',
#   'Greetings',
#   'Hello. I am ABHIbot. I will serve your leave enquiries.'],
#  ['hey, hello',
#   'Greetings',
#   'Hello. I am ABHIbot. I will serve your leave enquiries.'],
#  ['Good morning',
#   'Morning',
#   'Good Morning. I am ABHIbot. I will serve your leave enquiries.'],
#  ['Good afternoon',
#   'Afternoon',
#   'Good afternoon, I am ABHIbot. I will serve your leave enquiries.'],
#  ['Good evening',
#   'Evening',
#   'Good evening. I am ABHIbot. I will serve your leave enquiries.'],
#  ['Good night', 'Goodbye', 'Good night. Take care.'],
#  ['How are you today?', 'Opening', "I'm fine! Thank you. How can I help you?"],
#  ['want help', 'Help', 'How can I help you?'],
#  ['need help', 'Help', 'How can I help you?'],
#  ['I need a help', 'Help', 'How can I help you?'],
#  ['help me', 'Help', 'How can I help you?'],
#  ["I don't want your help.",
#   'No-Help',
#   'Ok sir/madam. No problem. Have a nice day.'],
#  ["I don't want your assistance",
#   'No-Help',
#   'Ok sir/madam. No problem. Have a nice day.'],
#  ['No help required', 'No-Help', 'Ok sir/madam. No problem. Have a nice day.'],
#  ['It has been great talking to you.',
#   'Closing',
#   'Itâ€˜s glad to know that I have been helpful. Have a good day!'],
#  ['great',
#   'Closing',
#   "It's glad to know that I have been helpful. Have a good day"],
#  ['thank you for your help',
#   'Closing',
#   "It's glad to know that I have been helpful. Have a good day!"],
#  ['thank you',
#   'Closing',
#   "It's glad to know that I have been helpful. Have a good day!"],
#  ['thank you very much',
#   'Closing',
#   "It's glad to know that I have been helpful. Have a good day!"],
#  ['thanks. ',
#   'Closing',
#   "You're welcome!It's glad to know that I have been helpful. Have a good day!"],
#  ['thanks very much',
#   'Closing',
#   "It's glad to know that I have been helpful. Have a good day!"],
#  ['Best places?',
#   'Best-Places',
#   'Thekkady,Munnar,Alleppey,Kochi,Wayanad,Varkala,Vagamon,Kumarakom,Kovalam,Periyar National Park,Poovar,Kollam,Idukki,Kozhikode,Bekal,Thrissur,Palakkad,Thalassery,Trivandrum,Nelliyampathy,Vythiri,Nilambur,Ponmudi,Kalpetta,Malampuzha,Kannur,Kasaragod,Kottayam'],
#  ['best place?',
#   'Best-Places',
#   'Thekkady,Munnar,Alleppey,Kochi,Wayanad,Varkala,Vagamon,Kumarakom,Kovalam,Periyar National Park,Poovar,Kollam,Idukki,Kozhikode,Bekal,Thrissur,Palakkad,Thalassery,Trivandrum,Nelliyampathy,Vythiri,Nilambur,Ponmudi,Kalpetta,Malampuzha,Kannur,Kasaragod,Kottayam'],
#  ['places in kerala to visit?',
#   'Best-Places',
#   'Thekkady,Munnar,Alleppey,Kochi,Wayanad,Varkala,Vagamon,Kumarakom,Kovalam,Periyar National Park,Poovar,Kollam,Idukki,Kozhikode,Bekal,Thrissur,Palakkad,Thalassery,Trivandrum,Nelliyampathy,Vythiri,Nilambur,Ponmudi,Kalpetta,Malampuzha,Kannur,Kasaragod,Kottayam'],
#  ['kerala tourist places?',
#   'Best-Places',
#   'Thekkady,Munnar,Alleppey,Kochi,Wayanad,Varkala,Vagamon,Kumarakom,Kovalam,Periyar National Park,Poovar,Kollam,Idukki,Kozhikode,Bekal,Thrissur,Palakkad,Thalassery,Trivandrum,Nelliyampathy,Vythiri,Nilambur,Ponmudi,Kalpetta,Malampuzha,Kannur,Kasaragod,Kottayam'],
#  ['best places to visit in kerala',
#   'Best-Places',
#   'Thekkady,Munnar,Alleppey,Kochi,Wayanad,Varkala,Vagamon,Kumarakom,Kovalam,Periyar National Park,Poovar,Kollam,Idukki,Kozhikode,Bekal,Thrissur,Palakkad,Thalassery,Trivandrum,Nelliyampathy,Vythiri,Nilambur,Ponmudi,Kalpetta,Malampuzha,Kannur,Kasaragod,Kottayam'],
#  ['best places in kerala',
#   'Best-Places',
#   'Thekkady,Munnar,Alleppey,Kochi,Wayanad,Varkala,Vagamon,Kumarakom,Kovalam,Periyar National Park,Poovar,Kollam,Idukki,Kozhikode,Bekal,Thrissur,Palakkad,Thalassery,Trivandrum,Nelliyampathy,Vythiri,Nilambur,Ponmudi,Kalpetta,Malampuzha,Kannur,Kasaragod,Kottayam'],
#  ['best locations',
#   'Best-Places',
#   'Thekkady,Munnar,Alleppey,Kochi,Wayanad,Varkala,Vagamon,Kumarakom,Kovalam,Periyar National Park,Poovar,Kollam,Idukki,Kozhikode,Bekal,Thrissur,Palakkad,Thalassery,Trivandrum,Nelliyampathy,Vythiri,Nilambur,Ponmudi,Kalpetta,Malampuzha,Kannur,Kasaragod,Kottayam'],
#  ['places',
#   'Best-Places',
#   'Thekkady,Munnar,Alleppey,Kochi,Wayanad,Varkala,Vagamon,Kumarakom,Kovalam,Periyar National Park,Poovar,Kollam,Idukki,Kozhikode,Bekal,Thrissur,Palakkad,Thalassery,Trivandrum,Nelliyampathy,Vythiri,Nilambur,Ponmudi,Kalpetta,Malampuzha,Kannur,Kasaragod,Kottayam'],
#  ['best places in india',
#   'India-Places',
#   'Currently I know about only kerala places.'],
#  ['places in india',
#   'India-Places',
#   'Currently I know about only kerala places.'],
#  ['What are the packages?', 'Select-Package', 'Select a place.'],
#  ['What are the pakages?', 'Select-Package', 'Select a place.'],
#  ['packages', 'Select-Package', 'Select a place.'],
#  ['tell me the packages', 'Select-Package', 'Select a place.'],
#  ['What are the packages for munnar?',
#   'Munnar-Package',
#   "The packages for munnar are,'Munnar, Alleppey, Kovalam', 'â‚¹ 18,900*', '4 Nights / 5 Days', 'Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Kochi, Munnar, Alleppey', 'â‚¹ 14,300*', '3 Nights / 4 Days','Munnar, Alleppey', 'â‚¹ 12,900*', '3 Nights / 4 Days',Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey', 'â‚¹ 28,700*', '7 Nights / 8 Days'."],
#  ['packages for munnar?',
#   'Munnar-Package',
#   "The packages for munnar are,'Munnar, Alleppey, Kovalam', 'â‚¹ 18,900*', '4 Nights / 5 Days', 'Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Kochi, Munnar, Alleppey', 'â‚¹ 14,300*', '3 Nights / 4 Days','Munnar, Alleppey', 'â‚¹ 12,900*', '3 Nights / 4 Days',Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey', 'â‚¹ 28,700*', '7 Nights / 8 Days'."],
#  ['munnar package',
#   'Munnar-Package',
#   "The packages for munnar are,'Munnar, Alleppey, Kovalam', 'â‚¹ 18,900*', '4 Nights / 5 Days', 'Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Kochi, Munnar, Alleppey', 'â‚¹ 14,300*', '3 Nights / 4 Days','Munnar, Alleppey', 'â‚¹ 12,900*', '3 Nights / 4 Days',Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey', 'â‚¹ 28,700*', '7 Nights / 8 Days'."],
#  ['munnar pakages',
#   'Munnar-Package',
#   "The packages for munnar are,'Munnar, Alleppey, Kovalam', 'â‚¹ 18,900*', '4 Nights / 5 Days', 'Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Kochi, Munnar, Alleppey', 'â‚¹ 14,300*', '3 Nights / 4 Days','Munnar, Alleppey', 'â‚¹ 12,900*', '3 Nights / 4 Days',Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey', 'â‚¹ 28,700*', '7 Nights / 8 Days'."],
#  ['tell me about munnar packages',
#   'Munnar-Package',
#   "The packages for munnar are,'Munnar, Alleppey, Kovalam', 'â‚¹ 18,900*', '4 Nights / 5 Days', 'Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Kochi, Munnar, Alleppey', 'â‚¹ 14,300*', '3 Nights / 4 Days','Munnar, Alleppey', 'â‚¹ 12,900*', '3 Nights / 4 Days',Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey', 'â‚¹ 28,700*', '7 Nights / 8 Days'."],
#  ['munnar',
#   'Munnar-Package',
#   "The packages for munnar are,'Munnar, Alleppey, Kovalam', 'â‚¹ 18,900*', '4 Nights / 5 Days', 'Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Kochi, Munnar, Alleppey', 'â‚¹ 14,300*', '3 Nights / 4 Days','Munnar, Alleppey', 'â‚¹ 12,900*', '3 Nights / 4 Days',Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey', 'â‚¹ 28,700*', '7 Nights / 8 Days'."],
#  ['packages in munnar',
#   'Munnar-Package',
#   "The packages for munnar are,'Munnar, Alleppey, Kovalam', 'â‚¹ 18,900*', '4 Nights / 5 Days', 'Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Kochi, Munnar, Alleppey', 'â‚¹ 14,300*', '3 Nights / 4 Days','Munnar, Alleppey', 'â‚¹ 12,900*', '3 Nights / 4 Days',Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey', 'â‚¹ 28,700*', '7 Nights / 8 Days'."],
#  ['Tell me about the hotels in munnar?',
#   'Munnar-Hotels',
#   '1. Chandys Drizzle Drops - Munnar Top Station-â‚¹23,540 onwards, 2. The Windy Mist Resort Munnar-â‚¹5,078 onwards, 3. The Mudhouse Marayoor-â‚¹8,000 onwards, 4. Sitaram Mountain Retreat-Enter dates\\nto see price, 5. Munnar Ice Queen Resorts-â‚¹3,500 onwards, 6. Pleasant Hill Resort-â‚¹4,000 onwards, 7. Chandys Windy Woods Munnar-â‚¹11,000 onwards, 8. Sprise Munnar Resort and Spa-â‚¹6,500 onwards, 9. Windermere Estate-â‚¹12,000 onwards, 10. The Wild Trails Munnar Resort-â‚¹10,400 onwards, 11. The Panoramic Getaway-â‚¹9,200 onwards, 12. Blanket Hotel & Spa-â‚¹10,000 onwards, 13. The Tall Trees
Blues-â‚¹622 onwards, 15. Edens Munnar-â‚¹3,185 onwards, 16. Misty Range Resorts-â‚¹5,000 onwards, 17. Riverbench Homestay Munnar, Anaviratty-â‚¹2,000 onwards, 18. Flower Valley Plantation Homestay-â‚¹3,980 onwards, 19. Blackberry Hills Munnar- Nature Resort & Spa-â‚¹8,000 onwards, 20. Chithirapuram Palace-â‚¹3,150 onwards, 21. The Nirvana Resort Munnar-â‚¹4,750 onwards, 22. Treebo Trend The Hazeberg Munnar With Mountain View-â‚¹4,580 onwards, 23. Maliyeckal Homestay-â‚¹1,440 onwards, 24. Thoppil Homestay Munnar-â‚¹2,200 onwards, 25. Grace Inn Munnar Homestay-â‚¹3,000 onwards, 26. Elephant Passage-â‚¹7,499 onwards, 27. Grand Plaza-â‚¹5,250 onwards, 28. The Leaf Munnar-â‚¹6,949 onwards, 29. The Fog Munnar (Resort & Spa)-â‚¹5,810 onwards, 30. Haze and Kites Resort Munnar-â‚¹9,333 onwards, 31. Zenha Resorts-â‚¹3,500 onwards, 32. Spicetree Munnar-Enter dates\\nto see price, 33. The Cliff Resort, Munnar-â‚¹4,500 onwards, 34. Lakezone Holiday Resort-â‚¹2,700 onwards, 35. Skylark Holidays Premium Chinnakkanal Munnar-â‚¹3,799 onwards, 36. Fab Valley Homestay-â‚¹2,000 onwards, "37. Nandanas Residency Munnar-â‚¹7,500 onwards", 38. Kurinji Wanderlust Resort Munnar-â‚¹1,999 onwards, 39. K Mansion-â‚¹850 onwards, "40. Scevas Garden Home-Enter dates\\nto see price", 41. Pepper county farm stay-â‚¹1,980 onwards, 42. View Valley Homestay-â‚¹1,700 onwards, 43. Green Valley Vista-â‚¹3,150 onwards, 44. Amber Dale Luxury Hotel & Spa, Munnar-â‚¹8,555 onwards, 45. Rivulet Resort-â‚¹8,550 onwards, 46. Fragrant Nature Munnar-â‚¹11,000 onwards, 47. The Siena Village-â‚¹5,500 onwards, 48. Deshadan Eco Valley Resort - An Eco friendly Mud House-Enter dates\\nto see price, 49. Mistletoe Homestay & Cafe-â‚¹11,000 onwards, 50. WinterHome homestay-â‚¹2,279 onwards'],
#  ['best Restaurants in munnar?',
#   'Munnar-Restaurant',
#   '1. Copper Castle - Restaurant, 2. SN Restaurant, 3. Sree Mahaveer Bhojanalaya, 4. Taste the Brews, 5. Saravana Bhavan, 6. Eastend, 7. DTPC Food Court, 8. Ali Baba & 41 Dishes.'],
#  ['Restaurants in munnar?',
#   'Munnar-Restaurant',
#   '1. Copper Castle - Restaurant, 2. SN Restaurant, 3. Sree Mahaveer Bhojanalaya, 4. Taste the Brews, 5. Saravana Bhavan, 6. Eastend, 7. DTPC Food Court, 8. Ali Baba & 41 Dishes.'],
#  ['restaurants in munnar?',
#   'Munnar-Restaurant',
#   '1. Copper Castle - Restaurant, 2. SN Restaurant, 3. Sree Mahaveer Bhojanalaya, 4. Taste the Brews, 5. Saravana Bhavan, 6. Eastend, 7. DTPC Food Court, 8. Ali Baba & 41 Dishes.'],
#  ['best Restaurants in munnar',
#   'Munnar-Restaurant',
#   '1. Copper Castle - Restaurant, 2. SN Restaurant, 3. Sree Mahaveer Bhojanalaya, 4. Taste the Brews, 5. Saravana Bhavan, 6. Eastend, 7. DTPC Food Court, 8. Ali Baba & 41 Dishes.'],
#  ['munnar restaurants',
#   'Munnar-Restaurant',
#   '1. Copper Castle - Restaurant, 2. SN Restaurant, 3. Sree Mahaveer Bhojanalaya, 4. Taste the Brews, 5. Saravana Bhavan, 6. Eastend, 7. DTPC Food Court, 8. Ali Baba & 41 Dishes.'],
#  ['munnar restaurant',
#   'Munnar-Restaurant',
#   '1. Copper Castle - Restaurant, 2. SN Restaurant, 3. Sree Mahaveer Bhojanalaya, 4. Taste the Brews, 5. Saravana Bhavan, 6. Eastend, 7. DTPC Food Court, 8. Ali Baba & 41 Dishes.'],
#  ['munnar restuarant',
#   'Munnar-Restaurant',
#   '1. Copper Castle - Restaurant, 2. SN Restaurant, 3. Sree Mahaveer Bhojanalaya, 4. Taste the Brews, 5. Saravana Bhavan, 6. Eastend, 7. DTPC Food Court, 8. Ali Baba & 41 Dishes.'],
#  ['munnar resturant',
#   'Munnar-Restaurant',
#   '1. Copper Castle - Restaurant, 2. SN Restaurant, 3. Sree Mahaveer Bhojanalaya, 4. Taste the Brews, 5. Saravana Bhavan, 6. Eastend, 7. DTPC Food Court, 8. Ali Baba & 41 Dishes.'],
#  ['What are the packages for alleppey?',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['packages for alappuzha?',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['packages for alleppey?',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['what are the packages for alappuzha?',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['alappuzha package',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['alleppy package',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['allepy package',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['aalappuzha package',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['tell me about alappuzha packages',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['alleppey',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['alappuzha',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['packages in alleppey',
#   'Alleppey-Package',
#   "The packages for Alleppey are,'Alleppey, Munnar', 'â‚¹ 11,500*', '2 Nights / 3 Days','Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Munnar, Thekkady, Alleppey, Kovalam', 'â‚¹ 28,000*', '6 Nights / 7 Days','Kochi, Alleppey, Varkala, Kollam', 'â‚¹ 20,300*', '7 Nights / 8 Days','Alleppey', 'â‚¹ 8,999*', '2 Nights / 3 Days'."],
#  ['Tell me about the hotels in Alleppey?',
#   'Alleppey-Hotels',
#   '1. Alleppey Beach Garden-â‚¹4,880 onwards, 2. Marari Beach Bungalow-â‚¹9,630 onwards, 3. Flamingo Boutique Villa-â‚¹7,499 onwards, 4. Lemon Dew Beach House-â‚¹1,200 onwards, 5. Ameya Kerala-â‚¹9,915 onwards, 6. Marari Beach Resort - CGH Earth-â‚¹21,779 onwards, 7. Bamboo Lagoon Backwater Front Resort-â‚¹4,000 onwards, 8. Venice Premium Houseboats Alleppey-â‚¹4,450 onwards, 9. Casa Orchid-â‚¹2,000 onwards, 10. Marari Green Villas-â‚¹4,950 onwards, 11. Kalappura Houseboats & Tours-â‚¹15,000 onwards, 12. Snehatheeram Homestay-â‚¹1,800 onwards, 13. Venice Iva Residency-â‚¹2,600 onwards, 14. Alleppey Haven Beach Villa-â‚¹4,900 onwards, 15. Marari Nest Beach Homestay-â‚¹2,800 onwards, 16. Bella Beach Villa-â‚¹1,000 onwards, 17. Marari Coastal Dreams Home Stay-â‚¹1,500 onwards, 18. Beachcampers only for backpackers-â‚¹300 onwards, 19. Venitia Homestay-â‚¹1,289 onwards, 20. Oceana Hills Residency-â‚¹2,088 onwards, 21. Abad Turtle Beach-â‚¹12,500 onwards, ""22. Marari Xaviers Inn-â‚¹2,660 onwards"", 23. Marari PeterLand-â‚¹1,650 onwards, 24. Marari Babu Homestay-â‚¹1,800 onwards, 25. Asthamaya Beach Homestay-â‚¹3,200 onwards, 26. Telma Beach Homestay-â‚¹1,490 onwards, 27. The Mayflower - Heritage Villa-â‚¹4,500 onwards, 28. Marari Ebin Charlys-â‚¹2,000 onwards, 29. Shalom Beach Residency-â‚¹1,699 onwards, 30. Treebo Tryst Vahada-â‚¹3,006 onwards, ""31. Johnsons Homestay - Ecohouseboat-â‚¹1,310 onwards"", 32. Neela Waters - Beach Home-â‚¹2,500 onwards, 33. Spice Coast Cruises Aleppy - Houseboat-â‚¹25,338 onwards, 34. Marari Adonis Beach Villa-â‚¹2,500 onwards, 35. Xandari Pearl Beach Resort-â‚¹17,000 onwards, 36. Orchid Lake View Homestay-â‚¹2,600 onwards, 37. Xandari Riverscapes-â‚¹38,500 onwards, 38. Marari Nadiya-â‚¹1,500 onwards, 39. Peacock Villa Marari-â‚¹2,500 onwards, 40. Malayalam Lake Resort-â‚¹2,188 onwards, 41. Punnamada Resort-â‚¹7,500 onwards, 42. Kalappura Homestay-â‚¹1,000 onwards, 43. Why Not Houseboat-â‚¹21,000 onwards, ""44. Noels beach homestay-â‚¹2,200 onwards"", 45. Keralan Homestay-â‚¹1,200 onwards, 46. Marari Beach House-â‚¹1,800 onwards, 47. Sunsets and Palm Trees-â‚¹12,500 onwards, 48. Marari Secret Beach Yoga Homestay-â‚¹1,500 onwards, 49. Collection O 81237 Remanso Resort-Enter dates\\nto see price, 50. Azure Tides Marari-â‚¹13,500 onwards"'],
#  ['Tell me about the hotels in alleppey?',
#   'Alleppey-Hotels',
#   '1. Alleppey Beach Garden-â‚¹4,880 onwards, 2. Marari Beach Bungalow-â‚¹9,630 onwards, 3. Flamingo Boutique Villa-â‚¹7,499 onwards, 4. Lemon Dew Beach House-â‚¹1,200 onwards, 5. Ameya Kerala-â‚¹9,915 onwards, 6. Marari Beach Resort - CGH Earth-â‚¹21,779 onwards, 7. Bamboo Lagoon Backwater Front Resort-â‚¹4,000 onwards, 8. Venice Premium Houseboats Alleppey-â‚¹4,450 onwards, 9. Casa Orchid-â‚¹2,000 onwards, 10. Marari Green Villas-â‚¹4,950 onwards, 11. Kalappura Houseboats & Tours-â‚¹15,000 onwards, 12. Snehatheeram Homestay-â‚¹1,800 onwards, 13. Venice Iva Residency-â‚¹2,600 onwards, 14. Alleppey Haven Beach Villa-â‚¹4,900 onwards, 15. Marari Nest Beach Homestay-â‚¹2,800 onwards, 16. Bella Beach Villa-â‚¹1,000 onwards, 17. Marari Coastal Dreams Home Stay-â‚¹1,500 onwards, 18. Beachcampers only for backpackers-â‚¹300 onwards, 19. Venitia Homestay-â‚¹1,289 onwards, 20. Oceana Hills Residency-â‚¹2,088 onwards, 21. Abad Turtle Beach-â‚¹12,500 onwards, ""22. Marari Xaviers Inn-â‚¹2,660 onwards"", 23. Marari PeterLand-â‚¹1,650 onwards, 24. Marari Babu Homestay-â‚¹1,800 onwards, 25. Asthamaya Beach Homestay-â‚¹3,200 onwards, 26. Telma Beach Homestay-â‚¹1,490 onwards, 27. The Mayflower - Heritage Villa-â‚¹4,500 onwards, 28. Marari Ebin Charlys-â‚¹2,000 onwards, 29. Shalom Beach Residency-â‚¹1,699 onwards, 30. Treebo Tryst Vahada-â‚¹3,006 onwards, ""31. Johnsons Homestay - Ecohouseboat-â‚¹1,310 onwards"", 32. Neela Waters - Beach Home-â‚¹2,500 onwards, 33. Spice Coast Cruises Aleppy - Houseboat-â‚¹25,338 onwards, 34. Marari Adonis Beach Villa-â‚¹2,500 onwards, 35. Xandari Pearl Beach Resort-â‚¹17,000 onwards, 36. Orchid Lake View Homestay-â‚¹2,600 onwards, 37. Xandari Riverscapes-â‚¹38,500 onwards, 38. Marari Nadiya-â‚¹1,500 onwards, 39. Peacock Villa Marari-â‚¹2,500 onwards, 40. Malayalam Lake Resort-â‚¹2,188 onwards, 41. Punnamada Resort-â‚¹7,500 onwards, 42. Kalappura Homestay-â‚¹1,000 onwards, 43. Why Not Houseboat-â‚¹21,000 onwards, ""44. Noels beach homestay-â‚¹2,200 onwards"", 45. Keralan Homestay-â‚¹1,200 onwards, 46. Marari Beach House-â‚¹1,800 onwards, 47. Sunsets and Palm Trees-â‚¹12,500 onwards, 48. Marari Secret Beach Yoga Homestay-â‚¹1,500 onwards, 49. Collection O 81237 Remanso Resort-Enter dates\\nto see price, 50. Azure Tides Marari-â‚¹13,500 onwards"'],
#  ['hotels in alleppey?',
#   'Alleppey-Hotels',
#   '1. Alleppey Beach Garden-â‚¹4,880 onwards, 2. Marari Beach Bungalow-â‚¹9,630 onwards, 3. Flamingo Boutique Villa-â‚¹7,499 onwards, 4. Lemon Dew Beach House-â‚¹1,200 onwards, 5. Ameya Kerala-â‚¹9,915 onwards, 6. Marari Beach Resort - CGH Earth-â‚¹21,779 onwards, 7. Bamboo Lagoon Backwater Front Resort-â‚¹4,000 onwards, 8. Venice Premium Houseboats Alleppey-â‚¹4,450 onwards, 9. Casa Orchid-â‚¹2,000 onwards, 10. Marari Green Villas-â‚¹4,950 onwards, 11. Kalappura Houseboats & Tours-â‚¹15,000 onwards, 12. Snehatheeram Homestay-â‚¹1,800 onwards, 13. Venice Iva Residency-â‚¹2,600 onwards, 14. Alleppey Haven Beach Villa-â‚¹4,900 onwards, 15. Marari Nest Beach Homestay-â‚¹2,800 onwards, 16. Bella Beach Villa-â‚¹1,000 onwards, 17. Marari Coastal Dreams Home Stay-â‚¹1,500 onwards, 18. Beachcampers only for backpackers-â‚¹300 onwards, 19. Venitia Homestay-â‚¹1,289 onwards, 20. Oceana Hills Residency-â‚¹2,088 onwards, 21. Abad Turtle Beach-â‚¹12,500 onwards, ""22. Marari Xaviers Inn-â‚¹2,660 onwards"", 23. Marari PeterLand-â‚¹1,650 onwards, 24. Marari Babu Homestay-â‚¹1,800 onwards, 25. Asthamaya Beach Homestay-â‚¹3,200 onwards, 26. Telma Beach Homestay-â‚¹1,490 onwards, 27. The Mayflower - Heritage Villa-â‚¹4,500 onwards, 28. Marari Ebin Charlys-â‚¹2,000 onwards, 29. Shalom Beach Residency-â‚¹1,699 onwards, 30. Treebo Tryst Vahada-â‚¹3,006 onwards, ""31. Johnsons Homestay - Ecohouseboat-â‚¹1,310 onwards"", 32. Neela Waters - Beach Home-â‚¹2,500 onwards, 33. Spice Coast Cruises Aleppy - Houseboat-â‚¹25,338 onwards, 34. Marari Adonis Beach Villa-â‚¹2,500 onwards, 35. Xandari Pearl Beach Resort-â‚¹17,000 onwards, 36. Orchid Lake View Homestay-â‚¹2,600 onwards, 37. Xandari Riverscapes-â‚¹38,500 onwards, 38. Marari Nadiya-â‚¹1,500 onwards, 39. Peacock Villa Marari-â‚¹2,500 onwards, 40. Malayalam Lake Resort-â‚¹2,188 onwards, 41. Punnamada Resort-â‚¹7,500 onwards, 42. Kalappura Homestay-â‚¹1,000 onwards, 43. Why Not Houseboat-â‚¹21,000 onwards, ""44. Noels beach homestay-â‚¹2,200 onwards"", 45. Keralan Homestay-â‚¹1,200 onwards, 46. Marari Beach House-â‚¹1,800 onwards, 47. Sunsets and Palm Trees-â‚¹12,500 onwards, 48. Marari Secret Beach Yoga Homestay-â‚¹1,500 onwards, 49. Collection O 81237 Remanso Resort-Enter dates\\nto see price, 50. Azure Tides Marari-â‚¹13,500 onwards"'],
#  ['hotels in alappuzha',
#   'Alleppey-Hotels',
#   '1. Alleppey Beach Garden-â‚¹4,880 onwards, 2. Marari Beach Bungalow-â‚¹9,630 onwards, 3. Flamingo Boutique Villa-â‚¹7,499 onwards, 4. Lemon Dew Beach House-â‚¹1,200 onwards, 5. Ameya Kerala-â‚¹9,915 onwards, 6. Marari Beach Resort - CGH Earth-â‚¹21,779 onwards, 7. Bamboo Lagoon Backwater Front Resort-â‚¹4,000 onwards, 8. Venice Premium Houseboats Alleppey-â‚¹4,450 onwards, 9. Casa Orchid-â‚¹2,000 onwards, 10. Marari Green Villas-â‚¹4,950 onwards, 11. Kalappura Houseboats & Tours-â‚¹15,000 onwards, 12. Snehatheeram Homestay-â‚¹1,800 onwards, 13. Venice Iva Residency-â‚¹2,600 onwards, 14. Alleppey Haven Beach Villa-â‚¹4,900 onwards, 15. Marari Nest Beach Homestay-â‚¹2,800 onwards, 16. Bella Beach Villa-â‚¹1,000 onwards, 17. Marari Coastal Dreams Home Stay-â‚¹1,500 onwards, 18. Beachcampers only for backpackers-â‚¹300 onwards, 19. Venitia Homestay-â‚¹1,289 onwards, 20. Oceana Hills Residency-â‚¹2,088 onwards, 21. Abad Turtle Beach-â‚¹12,500 onwards, ""22. Marari Xaviers Inn-â‚¹2,660 onwards"", 23. Marari PeterLand-â‚¹1,650 onwards, 24. Marari Babu Homestay-â‚¹1,800 onwards, 25. Asthamaya Beach Homestay-â‚¹3,200 onwards, 26. Telma Beach Homestay-â‚¹1,490 onwards, 27. The Mayflower - Heritage Villa-â‚¹4,500 onwards, 28. Marari Ebin Charlys-â‚¹2,000 onwards, 29. Shalom Beach Residency-â‚¹1,699 onwards, 30. Treebo Tryst Vahada-â‚¹3,006 onwards, ""31. Johnsons Homestay - Ecohouseboat-â‚¹1,310 onwards"", 32. Neela Waters - Beach Home-â‚¹2,500 onwards, 33. Spice Coast Cruises Aleppy - Houseboat-â‚¹25,338 onwards, 34. Marari Adonis Beach Villa-â‚¹2,500 onwards, 35. Xandari Pearl Beach Resort-â‚¹17,000 onwards, 36. Orchid Lake View Homestay-â‚¹2,600 onwards, 37. Xandari Riverscapes-â‚¹38,500 onwards, 38. Marari Nadiya-â‚¹1,500 onwards, 39. Peacock Villa Marari-â‚¹2,500 onwards, 40. Malayalam Lake Resort-â‚¹2,188 onwards, 41. Punnamada Resort-â‚¹7,500 onwards, 42. Kalappura Homestay-â‚¹1,000 onwards, 43. Why Not Houseboat-â‚¹21,000 onwards, ""44. Noels beach homestay-â‚¹2,200 onwards"", 45. Keralan Homestay-â‚¹1,200 onwards, 46. Marari Beach House-â‚¹1,800 onwards, 47. Sunsets and Palm Trees-â‚¹12,500 onwards, 48. Marari Secret Beach Yoga Homestay-â‚¹1,500 onwards, 49. Collection O 81237 Remanso Resort-Enter dates\\nto see price, 50. Azure Tides Marari-â‚¹13,500 onwards"'],
#  ['alappuzha hotels',
#   'Alleppey-Hotels',
#   '1. Alleppey Beach Garden-â‚¹4,880 onwards, 2. Marari Beach Bungalow-â‚¹9,630 onwards, 3. Flamingo Boutique Villa-â‚¹7,499 onwards, 4. Lemon Dew Beach House-â‚¹1,200 onwards, 5. Ameya Kerala-â‚¹9,915 onwards, 6. Marari Beach Resort - CGH Earth-â‚¹21,779 onwards, 7. Bamboo Lagoon Backwater Front Resort-â‚¹4,000 onwards, 8. Venice Premium Houseboats Alleppey-â‚¹4,450 onwards, 9. Casa Orchid-â‚¹2,000 onwards, 10. Marari Green Villas-â‚¹4,950 onwards, 11. Kalappura Houseboats & Tours-â‚¹15,000 onwards, 12. Snehatheeram Homestay-â‚¹1,800 onwards, 13. Venice Iva Residency-â‚¹2,600 onwards, 14. Alleppey Haven Beach Villa-â‚¹4,900 onwards, 15. Marari Nest Beach Homestay-â‚¹2,800 onwards, 16. Bella Beach Villa-â‚¹1,000 onwards, 17. Marari Coastal Dreams Home Stay-â‚¹1,500 onwards, 18. Beachcampers only for backpackers-â‚¹300 onwards, 19. Venitia Homestay-â‚¹1,289 onwards, 20. Oceana Hills Residency-â‚¹2,088 onwards, 21. Abad Turtle Beach-â‚¹12,500 onwards, ""22. Marari Xaviers Inn-â‚¹2,660 onwards"", 23. Marari PeterLand-â‚¹1,650 onwards, 24. Marari Babu Homestay-â‚¹1,800 onwards, 25. Asthamaya Beach Homestay-â‚¹3,200 onwards, 26. Telma Beach Homestay-â‚¹1,490 onwards, 27. The Mayflower - Heritage Villa-â‚¹4,500 onwards, 28. Marari Ebin Charlys-â‚¹2,000 onwards, 29. Shalom Beach Residency-â‚¹1,699 onwards, 30. Treebo Tryst Vahada-â‚¹3,006 onwards, ""31. Johnsons Homestay - Ecohouseboat-â‚¹1,310 onwards"", 32. Neela Waters - Beach Home-â‚¹2,500 onwards, 33. Spice Coast Cruises Aleppy - Houseboat-â‚¹25,338 onwards, 34. Marari Adonis Beach Villa-â‚¹2,500 onwards, 35. Xandari Pearl Beach Resort-â‚¹17,000 onwards, 36. Orchid Lake View Homestay-â‚¹2,600 onwards, 37. Xandari Riverscapes-â‚¹38,500 onwards, 38. Marari Nadiya-â‚¹1,500 onwards, 39. Peacock Villa Marari-â‚¹2,500 onwards, 40. Malayalam Lake Resort-â‚¹2,188 onwards, 41. Punnamada Resort-â‚¹7,500 onwards, 42. Kalappura Homestay-â‚¹1,000 onwards, 43. Why Not Houseboat-â‚¹21,000 onwards, ""44. Noels beach homestay-â‚¹2,200 onwards"", 45. Keralan Homestay-â‚¹1,200 onwards, 46. Marari Beach House-â‚¹1,800 onwards, 47. Sunsets and Palm Trees-â‚¹12,500 onwards, 48. Marari Secret Beach Yoga Homestay-â‚¹1,500 onwards, 49. Collection O 81237 Remanso Resort-Enter dates\\nto see price, 50. Azure Tides Marari-â‚¹13,500 onwards"'],
#  ['aleppey hotels',
#   'Alleppey-Hotels',
#   '1. Alleppey Beach Garden-â‚¹4,880 onwards, 2. Marari Beach Bungalow-â‚¹9,630 onwards, 3. Flamingo Boutique Villa-â‚¹7,499 onwards, 4. Lemon Dew Beach House-â‚¹1,200 onwards, 5. Ameya Kerala-â‚¹9,915 onwards, 6. Marari Beach Resort - CGH Earth-â‚¹21,779 onwards, 7. Bamboo Lagoon Backwater Front Resort-â‚¹4,000 onwards, 8. Venice Premium Houseboats Alleppey-â‚¹4,450 onwards, 9. Casa Orchid-â‚¹2,000 onwards, 10. Marari Green Villas-â‚¹4,950 onwards, 11. Kalappura Houseboats & Tours-â‚¹15,000 onwards, 12. Snehatheeram Homestay-â‚¹1,800 onwards, 13. Venice Iva Residency-â‚¹2,600 onwards, 14. Alleppey Haven Beach Villa-â‚¹4,900 onwards, 15. Marari Nest Beach Homestay-â‚¹2,800 onwards, 16. Bella Beach Villa-â‚¹1,000 onwards, 17. Marari Coastal Dreams Home Stay-â‚¹1,500 onwards, 18. Beachcampers only for backpackers-â‚¹300 onwards, 19. Venitia Homestay-â‚¹1,289 onwards, 20. Oceana Hills Residency-â‚¹2,088 onwards, 21. Abad Turtle Beach-â‚¹12,500 onwards, ""22. Marari Xaviers Inn-â‚¹2,660 onwards"", 23. Marari PeterLand-â‚¹1,650 onwards, 24. Marari Babu Homestay-â‚¹1,800 onwards, 25. Asthamaya Beach Homestay-â‚¹3,200 onwards, 26. Telma Beach Homestay-â‚¹1,490 onwards, 27. The Mayflower - Heritage Villa-â‚¹4,500 onwards, 28. Marari Ebin Charlys-â‚¹2,000 onwards, 29. Shalom Beach Residency-â‚¹1,699 onwards, 30. Treebo Tryst Vahada-â‚¹3,006 onwards, ""31. Johnsons Homestay - Ecohouseboat-â‚¹1,310 onwards"", 32. Neela Waters - Beach Home-â‚¹2,500 onwards, 33. Spice Coast Cruises Aleppy - Houseboat-â‚¹25,338 onwards, 34. Marari Adonis Beach Villa-â‚¹2,500 onwards, 35. Xandari Pearl Beach Resort-â‚¹17,000 onwards, 36. Orchid Lake View Homestay-â‚¹2,600 onwards, 37. Xandari Riverscapes-â‚¹38,500 onwards, 38. Marari Nadiya-â‚¹1,500 onwards, 39. Peacock Villa Marari-â‚¹2,500 onwards, 40. Malayalam Lake Resort-â‚¹2,188 onwards, 41. Punnamada Resort-â‚¹7,500 onwards, 42. Kalappura Homestay-â‚¹1,000 onwards, 43. Why Not Houseboat-â‚¹21,000 onwards, ""44. Noels beach homestay-â‚¹2,200 onwards"", 45. Keralan Homestay-â‚¹1,200 onwards, 46. Marari Beach House-â‚¹1,800 onwards, 47. Sunsets and Palm Trees-â‚¹12,500 onwards, 48. Marari Secret Beach Yoga Homestay-â‚¹1,500 onwards, 49. Collection O 81237 Remanso Resort-Enter dates\\nto see price, 50. Azure Tides Marari-â‚¹13,500 onwards"'],
#  ['Aleppey hotel',
#   'Alleppey-Hotels',
#   '1. Alleppey Beach Garden-â‚¹4,880 onwards, 2. Marari Beach Bungalow-â‚¹9,630 onwards, 3. Flamingo Boutique Villa-â‚¹7,499 onwards, 4. Lemon Dew Beach House-â‚¹1,200 onwards, 5. Ameya Kerala-â‚¹9,915 onwards, 6. Marari Beach Resort - CGH Earth-â‚¹21,779 onwards, 7. Bamboo Lagoon Backwater Front Resort-â‚¹4,000 onwards, 8. Venice Premium Houseboats Alleppey-â‚¹4,450 onwards, 9. Casa Orchid-â‚¹2,000 onwards, 10. Marari Green Villas-â‚¹4,950 onwards, 11. Kalappura Houseboats & Tours-â‚¹15,000 onwards, 12. Snehatheeram Homestay-â‚¹1,800 onwards, 13. Venice Iva Residency-â‚¹2,600 onwards, 14. Alleppey Haven Beach Villa-â‚¹4,900 onwards, 15. Marari Nest Beach Homestay-â‚¹2,800 onwards, 16. Bella Beach Villa-â‚¹1,000 onwards, 17. Marari Coastal Dreams Home Stay-â‚¹1,500 onwards, 18. Beachcampers only for backpackers-â‚¹300 onwards, 19. Venitia Homestay-â‚¹1,289 onwards, 20. Oceana Hills Residency-â‚¹2,088 onwards, 21. Abad Turtle Beach-â‚¹12,500 onwards, ""22. Marari Xaviers Inn-â‚¹2,660 onwards"", 23. Marari PeterLand-â‚¹1,650 onwards, 24. Marari Babu Homestay-â‚¹1,800 onwards, 25. Asthamaya Beach Homestay-â‚¹3,200 onwards, 26. Telma Beach Homestay-â‚¹1,490 onwards, 27. The Mayflower - Heritage Villa-â‚¹4,500 onwards, 28. Marari Ebin Charlys-â‚¹2,000 onwards, 29. Shalom Beach Residency-â‚¹1,699 onwards, 30. Treebo Tryst Vahada-â‚¹3,006 onwards, ""31. Johnsons Homestay - Ecohouseboat-â‚¹1,310 onwards"", 32. Neela Waters - Beach Home-â‚¹2,500 onwards, 33. Spice Coast Cruises Aleppy - Houseboat-â‚¹25,338 onwards, 34. Marari Adonis Beach Villa-â‚¹2,500 onwards, 35. Xandari Pearl Beach Resort-â‚¹17,000 onwards, 36. Orchid Lake View Homestay-â‚¹2,600 onwards, 37. Xandari Riverscapes-â‚¹38,500 onwards, 38. Marari Nadiya-â‚¹1,500 onwards, 39. Peacock Villa Marari-â‚¹2,500 onwards, 40. Malayalam Lake Resort-â‚¹2,188 onwards, 41. Punnamada Resort-â‚¹7,500 onwards, 42. Kalappura Homestay-â‚¹1,000 onwards, 43. Why Not Houseboat-â‚¹21,000 onwards, ""44. Noels beach homestay-â‚¹2,200 onwards"", 45. Keralan Homestay-â‚¹1,200 onwards, 46. Marari Beach House-â‚¹1,800 onwards, 47. Sunsets and Palm Trees-â‚¹12,500 onwards, 48. Marari Secret Beach Yoga Homestay-â‚¹1,500 onwards, 49. Collection O 81237 Remanso Resort-Enter dates\\nto see price, 50. Azure Tides Marari-â‚¹13,500 onwards"'],
#  ['Alleppey hotel',
#   'Alleppey-Hotels',
#   '1. Alleppey Beach Garden-â‚¹4,880 onwards, 2. Marari Beach Bungalow-â‚¹9,630 onwards, 3. Flamingo Boutique Villa-â‚¹7,499 onwards, 4. Lemon Dew Beach House-â‚¹1,200 onwards, 5. Ameya Kerala-â‚¹9,915 onwards, 6. Marari Beach Resort - CGH Earth-â‚¹21,779 onwards, 7. Bamboo Lagoon Backwater Front Resort-â‚¹4,000 onwards, 8. Venice Premium Houseboats Alleppey-â‚¹4,450 onwards, 9. Casa Orchid-â‚¹2,000 onwards, 10. Marari Green Villas-â‚¹4,950 onwards, 11. Kalappura Houseboats & Tours-â‚¹15,000 onwards, 12. Snehatheeram Homestay-â‚¹1,800 onwards, 13. Venice Iva Residency-â‚¹2,600 onwards, 14. Alleppey Haven Beach Villa-â‚¹4,900 onwards, 15. Marari Nest Beach Homestay-â‚¹2,800 onwards, 16. Bella Beach Villa-â‚¹1,000 onwards, 17. Marari Coastal Dreams Home Stay-â‚¹1,500 onwards, 18. Beachcampers only for backpackers-â‚¹300 onwards, 19. Venitia Homestay-â‚¹1,289 onwards, 20. Oceana Hills Residency-â‚¹2,088 onwards, 21. Abad Turtle Beach-â‚¹12,500 onwards, ""22. Marari Xaviers Inn-â‚¹2,660 onwards"", 23. Marari PeterLand-â‚¹1,650 onwards, 24. Marari Babu Homestay-â‚¹1,800 onwards, 25. Asthamaya Beach Homestay-â‚¹3,200 onwards, 26. Telma Beach Homestay-â‚¹1,490 onwards, 27. The Mayflower - Heritage Villa-â‚¹4,500 onwards, 28. Marari Ebin Charlys-â‚¹2,000 onwards, 29. Shalom Beach Residency-â‚¹1,699 onwards, 30. Treebo Tryst Vahada-â‚¹3,006 onwards, ""31. Johnsons Homestay - Ecohouseboat-â‚¹1,310 onwards"", 32. Neela Waters - Beach Home-â‚¹2,500 onwards, 33. Spice Coast Cruises Aleppy - Houseboat-â‚¹25,338 onwards, 34. Marari Adonis Beach Villa-â‚¹2,500 onwards, 35. Xandari Pearl Beach Resort-â‚¹17,000 onwards, 36. Orchid Lake View Homestay-â‚¹2,600 onwards, 37. Xandari Riverscapes-â‚¹38,500 onwards, 38. Marari Nadiya-â‚¹1,500 onwards, 39. Peacock Villa Marari-â‚¹2,500 onwards, 40. Malayalam Lake Resort-â‚¹2,188 onwards, 41. Punnamada Resort-â‚¹7,500 onwards, 42. Kalappura Homestay-â‚¹1,000 onwards, 43. Why Not Houseboat-â‚¹21,000 onwards, ""44. Noels beach homestay-â‚¹2,200 onwards"", 45. Keralan Homestay-â‚¹1,200 onwards, 46. Marari Beach House-â‚¹1,800 onwards, 47. Sunsets and Palm Trees-â‚¹12,500 onwards, 48. Marari Secret Beach Yoga Homestay-â‚¹1,500 onwards, 49. Collection O 81237 Remanso Resort-Enter dates\\nto see price, 50. Azure Tides Marari-â‚¹13,500 onwards"'],
#  ['best hotels in aleppey',
#   'Alleppey-Hotels',
#   '1. Alleppey Beach Garden-â‚¹4,880 onwards, 2. Marari Beach Bungalow-â‚¹9,630 onwards, 3. Flamingo Boutique Villa-â‚¹7,499 onwards, 4. Lemon Dew Beach House-â‚¹1,200 onwards, 5. Ameya Kerala-â‚¹9,915 onwards, 6. Marari Beach Resort - CGH Earth-â‚¹21,779 onwards, 7. Bamboo Lagoon Backwater Front Resort-â‚¹4,000 onwards, 8. Venice Premium Houseboats Alleppey-â‚¹4,450 onwards, 9. Casa Orchid-â‚¹2,000 onwards, 10. Marari Green Villas-â‚¹4,950 onwards, 11. Kalappura Houseboats & Tours-â‚¹15,000 onwards, 12. Snehatheeram Homestay-â‚¹1,800 onwards, 13. Venice Iva Residency-â‚¹2,600 onwards, 14. Alleppey Haven Beach Villa-â‚¹4,900 onwards, 15. Marari Nest Beach Homestay-â‚¹2,800 onwards, 16. Bella Beach Villa-â‚¹1,000 onwards, 17. Marari Coastal Dreams Home Stay-â‚¹1,500 onwards, 18. Beachcampers only for backpackers-â‚¹300 onwards, 19. Venitia Homestay-â‚¹1,289 onwards, 20. Oceana Hills Residency-â‚¹2,088 onwards, 21. Abad Turtle Beach-â‚¹12,500 onwards, ""22. Marari Xaviers Inn-â‚¹2,660 onwards"", 23. Marari PeterLand-â‚¹1,650 onwards, 24. Marari Babu Homestay-â‚¹1,800 onwards, 25. Asthamaya Beach Homestay-â‚¹3,200 onwards, 26. Telma Beach Homestay-â‚¹1,490 onwards, 27. The Mayflower - Heritage Villa-â‚¹4,500 onwards, 28. Marari Ebin Charlys-â‚¹2,000 onwards, 29. Shalom Beach Residency-â‚¹1,699 onwards, 30. Treebo Tryst Vahada-â‚¹3,006 onwards, ""31. Johnsons Homestay - Ecohouseboat-â‚¹1,310 onwards"", 32. Neela Waters - Beach Home-â‚¹2,500 onwards, 33. Spice Coast Cruises Aleppy - Houseboat-â‚¹25,338 onwards, 34. Marari Adonis Beach Villa-â‚¹2,500 onwards, 35. Xandari Pearl Beach Resort-â‚¹17,000 onwards, 36. Orchid Lake View Homestay-â‚¹2,600 onwards, 37. Xandari Riverscapes-â‚¹38,500 onwards, 38. Marari Nadiya-â‚¹1,500 onwards, 39. Peacock Villa Marari-â‚¹2,500 onwards, 40. Malayalam Lake Resort-â‚¹2,188 onwards, 41. Punnamada Resort-â‚¹7,500 onwards, 42. Kalappura Homestay-â‚¹1,000 onwards, 43. Why Not Houseboat-â‚¹21,000 onwards, ""44. Noels beach homestay-â‚¹2,200 onwards"", 45. Keralan Homestay-â‚¹1,200 onwards, 46. Marari Beach House-â‚¹1,800 onwards, 47. Sunsets and Palm Trees-â‚¹12,500 onwards, 48. Marari Secret Beach Yoga Homestay-â‚¹1,500 onwards, 49. Collection O 81237 Remanso Resort-Enter dates\\nto see price, 50. Azure Tides Marari-â‚¹13,500 onwards
niraamaya Wellness Retreats, Surya Samudra, Kovalam-â‚¹13,500 onwards, 45. Moon Valley Cottage-â‚¹1,287 onwards, 46. Ganesh Ayurveda Holiday Home bed and breakfast-â‚¹2,400 onwards, 47. Ekana Homes-â‚¹2,250 onwards, 48. SFS Homebridge @ City-â‚¹4,275 onwards, 49. The Terrace by Ladder Mgd by Citrine-â‚¹3,950 onwards, 50. Abad Harmonia Ayurvedic Beach Resort-â‚¹4,910 onwards"'],
#  ['best Restaurants in trivandrum',
#   'Trivandrum-Restaurant',
#   '1. Ananda Bhavan, 2. Cherries & Berries, ""3. Tiffanys Restaurant"", 4. Ariya Nivaas, 5. Vibhav, 6. Bread Factory, 7. Indian Coffee House, 8. Regency Restaurant, 9. Villa Maya, 10. Azad'],
#  ['Restaurants in trivandrum',
#   'Trivandrum-Restaurant',
#   '1. Ananda Bhavan, 2. Cherries & Berries, ""3. Tiffanys Restaurant"", 4. Ariya Nivaas, 5. Vibhav, 6. Bread Factory, 7. Indian Coffee House, 8. Regency Restaurant, 9. Villa Maya, 10. Azad'],
#  ['restaurants in trivandrum',
#   'Trivandrum-Restaurant',
#   '1. Ananda Bhavan, 2. Cherries & Berries, ""3. Tiffanys Restaurant"", 4. Ariya Nivaas, 5. Vibhav, 6. Bread Factory, 7. Indian Coffee House, 8. Regency Restaurant, 9. Villa Maya, 10. Azad'],
#  ['best Restaurants in trivandrum',
#   'Trivandrum-Restaurant',
#   '1. Ananda Bhavan, 2. Cherries & Berries, ""3. Tiffanys Restaurant"", 4. Ariya Nivaas, 5. Vibhav, 6. Bread Factory, 7. Indian Coffee House, 8. Regency Restaurant, 9. Villa Maya, 10. Azad'],
#  ['trivandrum restaurants',
#   'Trivandrum-Restaurant',
#   '1. Ananda Bhavan, 2. Cherries & Berries, ""3. Tiffanys Restaurant"", 4. Ariya Nivaas, 5. Vibhav, 6. Bread Factory, 7. Indian Coffee House, 8. Regency Restaurant, 9. Villa Maya, 10. Azad'],
#  ['thiruvananthapuram restaurants',
#   'Trivandrum-Restaurant',
#   '1. Ananda Bhavan, 2. Cherries & Berries, ""3. Tiffanys Restaurant"", 4. Ariya Nivaas, 5. Vibhav, 6. Bread Factory, 7. Indian Coffee House, 8. Regency Restaurant, 9. Villa Maya, 10. Azad'],
#  ['thiruvananthapuram',
#   'Trivandrum-Restaurant',
#   '1. Ananda Bhavan, 2. Cherries & Berries, ""3. Tiffanys Restaurant"", 4. Ariya Nivaas, 5. Vibhav, 6. Bread Factory, 7. Indian Coffee House, 8. Regency Restaurant, 9. Villa Maya, 10. Azad'],
#  ['What are the packages for thekkady?',
#   'Thekkady-Package',
#   'The packages for Thekkady are,"\'Thekkady\', \'â‚¹ 7,525*\', \'2 Nights / 3 Days\'","\'Munnar, Thekkady\', \'â‚¹ 13,700*\', \'3 Nights / 4 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 12,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 19,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey\', \'â‚¹ 28,700*\', \'7 Nights / 8 Days\'"\''],
#  ['packages for thekkady',
#   'Thekkady-Package',
#   'The packages for Thekkady are,"\'Thekkady\', \'â‚¹ 7,525*\', \'2 Nights / 3 Days\'","\'Munnar, Thekkady\', \'â‚¹ 13,700*\', \'3 Nights / 4 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 12,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 19,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey\', \'â‚¹ 28,700*\', \'7 Nights / 8 Days\'"'],
#  ['thekkady package',
#   'Thekkady-Package',
#   'The packages for Thekkady are,"\'Thekkady\', \'â‚¹ 7,525*\', \'2 Nights / 3 Days\'","\'Munnar, Thekkady\', \'â‚¹ 13,700*\', \'3 Nights / 4 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 12,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 19,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey\', \'â‚¹ 28,700*\', \'7 Nights / 8 Days\'"'],
#  ['thekkady pakages',
#   'Thekkady-Package',
#   'The packages for Thekkady are,"\'Thekkady\', \'â‚¹ 7,525*\', \'2 Nights / 3 Days\'","\'Munnar, Thekkady\', \'â‚¹ 13,700*\', \'3 Nights / 4 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 12,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 19,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey\', \'â‚¹ 28,700*\', \'7 Nights / 8 Days\'"'],
#  ['tell me about thekkady packages',
#   'Thekkady-Package',
#   'The packages for Thekkady are,"\'Thekkady\', \'â‚¹ 7,525*\', \'2 Nights / 3 Days\'","\'Munnar, Thekkady\', \'â‚¹ 13,700*\', \'3 Nights / 4 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 12,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 19,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey\', \'â‚¹ 28,700*\', \'7 Nights / 8 Days\'"'],
#  ['Thekkady package',
#   'Thekkady-Package',
#   'The packages for Thekkady are,"\'Thekkady\', \'â‚¹ 7,525*\', \'2 Nights / 3 Days\'","\'Munnar, Thekkady\', \'â‚¹ 13,700*\', \'3 Nights / 4 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 12,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 19,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey\', \'â‚¹ 28,700*\', \'7 Nights / 8 Days\'"'],
#  ['packages in thekkady',
#   'Thekkady-Package',
#   'The packages for Thekkady are,"\'Thekkady\', \'â‚¹ 7,525*\', \'2 Nights / 3 Days\'","\'Munnar, Thekkady\', \'â‚¹ 13,700*\', \'3 Nights / 4 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 12,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 19,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey\', \'â‚¹ 28,700*\', \'7 Nights / 8 Days\'"'],
#  ['thekkady',
#   'Thekkady-Package',
#   'The packages for Thekkady are,"\'Thekkady\', \'â‚¹ 7,525*\', \'2 Nights / 3 Days\'","\'Munnar, Thekkady\', \'â‚¹ 13,700*\', \'3 Nights / 4 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 12,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 19,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey\', \'â‚¹ 28,700*\', \'7 Nights / 8 Days\'"'],
#  ['packages in thekkady',
#   'Thekkady-Package',
#   'The packages for Thekkady are,"\'Thekkady\', \'â‚¹ 7,525*\', \'2 Nights / 3 Days\'","\'Munnar, Thekkady\', \'â‚¹ 13,700*\', \'3 Nights / 4 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 12,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 19,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey\', \'â‚¹ 28,700*\', \'7 Nights / 8 Days\'"']]

# %%
features_data, corpus, answers = extract_feature_from_doc(data)

# %%
print(features_data[50])
# Out:
# ({'tell': True, 'hotel': True, 'munnar': True}, 'Munnar-Hotels')

# %%
corpus
# Out:
# ['hello',
#  'hi',
#  'hello',
#  'hi',
#  'hi',
#  'hi',
#  'hey',
#  'hello',
#  'hi',
#  'hey',
#  'hey',
#  'hi',
#  'hey',
#  'hello',
#  'good',
#  'morn',
#  'good',
#  'afternoon',
#  'good',
#  'even',
#  'good',
#  'night',
#  'today',
#  'want',
#  'help',
#  'need',
#  'help',
#  'need',
#  'help',
#  'help',
#  'want',
#  'help',
#  'want',
#  'assist',
#  'help',
#  'great',
#  'talk',
#  'great',
#  'thank',
#  'help',
#  'thank',
#  'thank',
#  'much',
#  'thank',
#  'thank',
#  'much',
#  'place',
#  'place',
#  'place',
#  'kerala',
#  'visit',
#  'kerala',
#  'tourist',
#  'place',
#  'place',
#  'visit',
#  'kerala',
#  'place',
#  'kerala',
#  'locat',
#  'place',
#  'place',
#  'india',
#  'place',
#  'india',
#  'packag',
#  'pakag',
#  'packag',
#  'tell',
#  'packag',
#  'packag',
#  'munnar',
#  'packag',
#  'munnar',
#  'munnar',
#  'packag',
#  'munnar',
#  'pakag',
#  'munnar',
#  'packag',
#  'munnar',
#  'packag',
#  'munnar',
#  'tell',
#  'hotel',
#  'munnar',
#  'hotel',
#  'munnar',
#  'munnar',
#  'hotel',
#  'hotel',
#  'munnar',
#  'restaur',
#  'munnar',
#  'restaur',
#  'munnar',
#  'restaur',
#  'munnar',
#  'restaur',
#  'munnar',
#  'munnar',
#  'restaur',
#  'munnar',
#  'restaur',
#  'munnar',
#  'restuar',
#  'munnar',
#  'restur',
#  'packag',
#  'alleppey',
#  'packag',
#  'alappuzha',
#  'packag',
#  'alleppey',
#  'packag',
#  'alappuzha',
#  'alappuzha',
#  'packag',
#  'alleppi',
#  'packag',
#  'allepi',
#  'packag',
#  'aalappuzha',
#  'packag',
#  'alappuzha',
#  'packag',
#  'alleppey',
#  'alappuzha',
#  'packag',
#  'alleppey',
#  'tell',
#  'hotel',
#  'alleppey',
#  'tell',
#  'hotel',
#  'alleppey',
#  'hotel',
#  'alleppey',
#  'hotel',
#  'alappuzha',
#  'alappuzha',
#  'hotel',
#  'aleppey',
#  'hotel',
#  'aleppey',
#  'hotel',
#  'alleppey',
#  'hotel',
#  'hotel',
#  'aleppey',
#  'hotel',
#  'alleppey',
#  'hotel',
#  'alappuzha',
#  'hotel',
#  'aalappuzha',
#  'restaur',
#  'alleppey',
#  'restaur',
#  'aleppey',
#  'restaur',
#  'alappuzha',
#  'restaur',
#  'alappuzha',
#  'restaur',
#  'alleppey',
#  'restaur',
#  'aleppey',
#  'restaur',
#  'allepey',
#  'restaur',
#  'allepi',
#  'restaur',
#  'alappuzha',
#  'restaur',
#  'alappuzha',
#  'alappuzha',
#  'restaur',
#  'alleppey',
#  'restaur',
#  'aleppi',
#  'restuar',
#  'alleppi',
#  'restur',
#  'restur',
#  'alappuzha',
#  'packag',
#  'kochi',
#  'packag',
#  'kochi',
#  'kochi',
#  'packag',
#  'kochi',
#  'pakag',
#  'kochi',
#  'packag',
#  'ernakulam',
#  'packag',
#  'packag',
#  'kochi',
#  'kochi',
#  'packag',
#  'kochi',
#  'tell',
#  'hotel',
#  'kochi',
#  'hotel',
#  'kochi',
#  'kochi',
#  'hotel',
#  'ernakulam',
#  'hotel',
#  'hotel',
#  'kochi',
#  'restaur',
#  'restaur',
#  'kochi',
#  'restaur',
#  'kochi',
#  'restaur',
#  'kochi',
#  'restaur',
#  'kochi',
#  'restaur',
#  'kochi',
#  'restuar',
#  'kochi',
#  'restur',
#  'packag',
#  'wayanad',
#  'packag',
#  'wayanad',
#  'wayanad',
#  'packag',
#  'wayanad',
#  'pakag',
#  'wayanad',
#  'packag',
#  'wayanad',
#  'packag',
#  'wayanad',
#  'tell',
#  'hotel',
#  'wayanad',
#  'hotel',
#  'wayanad',
#  'wayanad',
#  'hotel',
#  'hotel',
#  'wayanad',
#  'restaur',
#  'wayanad',
#  'restaur',
#  'wayanad',
#  'restaur',
#  'wayanad',
#  'restaur',
#  'wayanad',
#  'wayanad',
#  'restaur',
#  'wayanad',
#  'restaur',
#  'wayanad',
#  'restuar',
#  'wayanad',
#  'restur',
#  'packag',
#  'varkala',
#  'packag',
#  'varkala',
#  'varkala',
#  'pakag',
#  'packag',
#  'varkala',
#  'varkala',
#  'packag',
#  'varkala',
#  'pakag',
#  'varkala',
#  'packag',
#  'varkala',
#  'packag',
#  'varkala',
#  'tell',
#  'hotel',
#  'varkala',
#  'hotel',
#  'varkala',
#  'varkala',
#  'hotel',
#  'hotel',
#  'varkala',
#  'restaur',
#  'varkala',
#  'restaur',
#  'varkala',
#  'restaur',
#  'varkala',
#  'restaur',
#  'varkala',
#  'varkala',
#  'restaur',
#  'varkala',
#  'restaur',
#  'varkala',
#  'restuar',
#  'varkala',
#  'restur',
#  'packag',
#  'kovalam',
#  'packag',
#  'kovalam',
#  'kovalam',
#  'packag',
#  'kovalam',
#  'pakag',
#  'kovalam',
#  'packag',
#  'kovalam',
#  'packag',
#  'kovalam',
#  'tell',
#  'hotel',
#  'kovalam',
#  'hotel',
#  'kovalam',
#  'kovalam',
#  'hotel',
#  'hotel',
#  'kovalam',
#  'restaur',
#  'restaur',
#  'kovalam',
#  'restaur',
#  'kovalam',
#  'restaur',
#  'kovalam',
#  'restaur',
#  'packag',
#  'kumarakom',
#  'packag',
#  'kovalam',
#  'kumarakom',
#  'packag',
#  'kumarakom',
#  'pakag',
#  'kumarakom',
#  'packag',
#  'kumarakom',
#  'packag',
#  'kumarakom',
#  'tell',
#  'hotel',
#  'kumarakom',
#  'hotel',
#  'kumarakom',
#  'kumarakom',
#  'hotel',
#  'hotel',
#  'kumarakom',
#  'restaur',
#  'restaur',
#  'kumarakom',
#  'restaur',
#  'kumarakom',
#  'restaur',
#  'kumarakom',
#  'restaur',
#  'packag',
#  'vagamon',
#  'packag',
#  'vagamon',
#  'vagamon',
#  'packag',
#  'vagamon',
#  'pakag',
#  'tell',
#  'vagamon',
#  'packag',
#  'vagamon',
#  'packag',
#  'vagamon',
#  'tell',
#  'hotel',
#  'kumarakom',
#  'hotel',
#  'vagamon',
#  'vagamon',
#  'hotel',
#  'hotel',
#  'vagamon',
#  'restaur',
#  'vagamon',
#  'restaur',
#  'vagamon',
#  'restaur',
#  'vagamon',
#  'restaur',
#  'vagamon',
#  'vagamon',
#  'restaur',
#  'packag',
#  'periyar',
#  'nation',
#  'park',
#  'packag',
#  'periyar',
#  'nation',
#  'park',
#  'periyar',
#  'nation',
#  'park',
#  'packag',
#  'periyar',
#  'nation',
#  'park',
#  'pakag',
#  'periyar',
#  'nation',
#  'park',
#  'packag',
#  'periyar',
#  'pakag',
#  'periyar',
#  'nation',
#  'park',
#  'packag',
#  'periyar',
#  'packag',
#  'periyar',
#  'nation',
#  'park',
#  'packag',
#  'periyar',
#  'nation',
#  'park',
#  'tell',
#  'hotel',
#  'periyar',
#  'nation',
#  'park',
#  'hotel',
#  'periyar',
#  'nation',
#  'park',
#  'periyar',
#  'nation',
#  'park',
#  'hotel',
#  'hotel',
#  'periyar',
#  'nation',
#  'park',
#  'periyar',
#  'hotel',
#  'restaur',
#  'periyar',
#  'nation',
#  'park',
#  'restaur',
#  'periyar',
#  'nation',
#  'park',
#  'restaur',
#  'periyar',
#  'nation',
#  'park',
#  'restaur',
#  'periyar',
#  'nation',
#  'park',
#  'periyar',
#  'nation',
#  'park',
#  'restaur',
#  'periyar',
#  'restaur',
#  'packag',
#  'idukki',
#  'packag',
#  'idukki',
#  'idukki',
#  'packag',
#  'idukki',
#  'packag',
#  'idukki',
#  'pakag',
#  'idukki',
#  'packag',
#  'idukki',
#  'packag',
#  'idukki',
#  'tell',
#  'hotel',
#  'idukki',
#  'hotel',
#  'idukki',
#  'idukki',
#  'hotel',
#  'hotel',
#  'idukki',
#  'restaur',
#  'idukki',
#  'restaur',
#  'idukki',
#  'restaur',
#  'idukki',
#  'restaur',
#  'idukki',
#  'idukki',
#  'restaur',
#  'packag',
#  'kozhikod',
#  'calicut',
#  'pakag',
#  'kozhikod',
#  'packag',
#  'kozhikod',
#  'packag',
#  'calicut',
#  'packag',
#  'kozhikod',
#  'packag',
#  'calicut',
#  'kozhikod',
#  'packag',
#  'calicut',
#  'packag',
#  'kozhikod',
#  'pakag',
#  'tell',
#  'kozhikod',
#  'packag',
#  'kozhikod',
#  'packag',
#  'kozhikod',
#  'tell',
#  'hotel',
#  'kozhikod',
#  'hotel',
#  'kozhikod',
#  'hotel',
#  'calicut',
#  'kozhikod',
#  'hotel',
#  'calicut',
#  'hotel',
#  'hotel',
#  'kozhikod',
#  'restaur',
#  'restaur',
#  'restaur',
#  'restaur',
#  'restaur',
#  'restaur',
#  'kozhikod',
#  'restaur',
#  'kozhikod',
#  'restaur',
#  'calicut',
#  'restaur',
#  'calicut',
#  'restur',
#  'packag',
#  'nilambur',
#  'packag',
#  'nilambur',
#  'nilambur',
#  'packag',
#  'nilambur',
#  'pakag',
#  'nilambur',
#  'packag',
#  'nilambur',
#  'packag',
#  'nilambur',
#  'nilamboor',
#  'packag',
#  'nilambur',
#  'nilambur',
#  'pakag',
#  'nilamboor',
#  'pakag',
#  'tell',
#  'hotel',
#  'nilambur',
#  'hotel',
#  'nilambur',
#  'nilambur',
#  'hotel',
#  'nilamboor',
#  'hotel',
#  'nilamboor',
#  'hotel',
#  'hotel',
#  'nilambur',
#  'restaur',
#  'nilambur',
#  'restaur',
#  'nilambur',
#  'restaur',
#  'nilambur',
#  'restaur',
#  'nilambur',
#  'nilambur',
#  'restaur',
#  'nilamboor',
#  'restaur',
#  'nilambur',
#  'restaur',
#  'packag',
#  'thrissur',
#  'packag',
#  'thrissur',
#  'thrissur',
#  'packag',
#  'thrissur',
#  'pakag',
#  'thrissur',
#  'packag',
#  'thrissur',
#  'packag',
#  'thrissur',
#  'tell',
#  'hotel',
#  'thrissur',
#  'hotel',
#  'thrissur',
#  'thrissur',
#  'hotel',
#  'trissur',
#  'hotel',
#  'thrissoor',
#  'hotel',
#  'thrissur',
#  'hotel',
#  'hotel',
#  'thrissur',
#  'restaur',
#  'thrissur',
#  'restaur',
#  'thrissur',
#  'restaur',
#  'thrissur',
#  'restaur',
#  'thrissur',
#  'thrissur',
#  'restaur',
#  'thrissur',
#  'restur',
#  'thrissoor',
#  'restaur',
#  'thrissoor',
#  'restur',
#  'packag',
#  'trivandrum',
#  'packag',
#  'trivandrum',
#  'packag',
#  'thiruvananthapuram',
#  'trivandrum',
#  'pakag',
#  'thiruvananthapuram',
#  'pakag',
#  'thiruvananthapuram',
#  'packag',
#  'packag',
#  'kochi',
#  'trivandrum',
#  'packag',
#  'trivandrum',
#  'pakag',
#  'trivandrum',
#  'packag',
#  'trivandrum',
#  'packag',
#  'trivandrum',
#  'tell',
#  'hotel',
#  'trivandrum',
#  'hotel',
#  'trivandrum',
#  'trivandrum',
#  'hotel',
#  'thiruvananthapuram',
#  'hotel',
#  'hotel',
#  'trivandrum',
#  'restaur',
#  'trivandrum',
#  'restaur',
#  'trivandrum',
#  'restaur',
#  'trivandrum',
#  'restaur',
#  'trivandrum',
#  'trivandrum',
#  'restaur',
#  'thiruvananthapuram',
#  'restaur',
#  'thiruvananthapuram',
#  'packag',
#  'thekkadi',
#  'packag',
#  'thekkadi',
#  'thekkadi',
#  'packag',
#  'thekkadi',
#  'pakag',
#  'thekkadi',
#  'packag',
#  'thekkadi',
#  'packag',
#  'packag',
#  'thekkadi',
#  'thekkadi',
#  'packag',
#  'thekkadi']

# %%
answers
# Out:
# {'Greetings': 'Hello. I am ABHIbot. I will serve your leave enquiries.',
#  'Morning': 'Good Morning. I am ABHIbot. I will serve your leave enquiries.',
#  'Afternoon': 'Good afternoon, I am ABHIbot. I will serve your leave enquiries.',
#  'Evening': 'Good evening. I am ABHIbot. I will serve your leave enquiries.',
#  'Goodbye': 'Good night. Take care.',
#  'Opening': "I'm fine! Thank you. How can I help you?",
#  'Help': 'How can I help you?',
#  'No-Help': 'Ok sir/madam. No problem. Have a nice day.',
#  'Closing': "It's glad to know that I have been helpful. Have a good day!",
#  'Best-Places': 'Thekkady,Munnar,Alleppey,Kochi,Wayanad,Varkala,Vagamon,Kumarakom,Kovalam,Periyar National Park,Poovar,Kollam,Idukki,Kozhikode,Bekal,Thrissur,Palakkad,Thalassery,Trivandrum,Nelliyampathy,Vythiri,Nilambur,Ponmudi,Kalpetta,Malampuzha,Kannur,Kasaragod,Kottayam',
#  'India-Places': 'Currently I know about only kerala places.',
#  'Select-Package': 'Select a place.',
#  'Munnar-Package': "The packages for munnar are,'Munnar, Alleppey, Kovalam', 'â‚¹ 18,900*', '4 Nights / 5 Days', 'Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Kochi, Munnar, Alleppey', 'â‚¹ 14,300*', '3 Nights / 4 Days','Munnar, Alleppey', 'â‚¹ 12,900*', '3 Nights / 4 Days',Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey', 'â‚¹ 28,700*', '7 Nights / 8 Days'.",
#  'Munnar-Hotels': '1. Chandys Drizzle Drops - Munnar Top Station-â‚¹23,540 onwards, 2. The Windy Mist Resort Munnar-â‚¹5,078 onwards, 3. The Mudhouse Marayoor-â‚¹8,000 onwards, 4. Sitaram Mountain Retreat-Enter dates\\nto see price, 5. Munnar Ice Queen Resorts-â‚¹3,500 onwards, 6. Pleasant Hill Resort-â‚¹4,000 onwards, 7. Chandys Windy Woods Munnar-â‚¹11,000 onwards, 8. Sprise Munnar Resort and Spa-â‚¹6,500 onwards, 9. Windermere Estate-â‚¹12,000 onwards, 10. The Wild Trails Munnar Resort-â‚¹10,400 onwards, 11. The Panoramic Getaway-â‚¹9,200 onwards, 12. Blanket Hotel & Spa-â‚¹10,000 onwards, 13. The Tall Trees Munnar-â‚¹8,396 onwards, 14. OYO Flagship 81098 Nature Blues-â‚¹622 onwards, 15. Edens Munnar-â‚¹3,185 onwards, 16. Misty Range Resorts-â‚¹5,000 onwards, 17. Riverbench Homestay Munnar, Anaviratty-
 onwards, 25. AMARA AYURVEDA RETREAT- Overlooking Evergreen Western Ghats an ecologically sustainable living space in Kovalam-â‚¹5,500 onwards, 26. Soma Manaltheeram Ayurveda BeachVillage-Enter dates\\nto see price, ""27. Anithas Garden Stay-â‚¹2,340 onwards"", 28. NALINAM HOMESTAY-â‚¹1,377 onwards, 29. Amritham Holidays Homestay Trivandrum-â‚¹2,800 onwards, 30. Vivanta Thiruvananthapuram-â‚¹6,000 onwards, 31. The Central Residency-â‚¹3,500 onwards, 32. The Travancore Heritage Beach Resort-â‚¹9,500 onwards, 33. Sky Palace Beach Hotel-â‚¹1,510 onwards, 34. Over The Hill-â‚¹6,600 onwards, 35. RAMAS GARDEN-â‚¹2,016 onwards, 36. Mayoorapanjaram-â‚¹1,200 onwards, 37. The Ayur Villa-â‚¹8,500 onwards, 38. Mary Land Homestay-â‚¹2,900 onwards, ""39. Queens-â‚¹1,850 onwards"", 40. HYCINTH Hotels-â‚¹7,000 onwards, 41. Dimora Hotels And Resorts-â‚¹4,750 onwards, 42. Uday Suites - The Airport Hotel-â‚¹7,599 onwards, 43. DOWN TOWN HOLIDAYS-â‚¹2,850 onwards, 44. Niraamaya Wellness Retreats, Surya Samudra, Kovalam-â‚¹13,500 onwards, 45. Moon Valley Cottage-â‚¹1,287 onwards, 46. Ganesh Ayurveda Holiday Home bed and breakfast-â‚¹2,400 onwards, 47. Ekana Homes-â‚¹2,250 onwards, 48. SFS Homebridge @ City-â‚¹4,275 onwards, 49. The Terrace by Ladder Mgd by Citrine-â‚¹3,950 onwards, 50. Abad Harmonia Ayurvedic Beach Resort-â‚¹4,910 onwards"',
#  'Trivandrum-Restaurant': '1. Ananda Bhavan, 2. Cherries & Berries, ""3. Tiffanys Restaurant"", 4. Ariya Nivaas, 5. Vibhav, 6. Bread Factory, 7. Indian Coffee House, 8. Regency Restaurant, 9. Villa Maya, 10. Azad',
#  'Thekkady-Package': 'The packages for Thekkady are,"\'Thekkady\', \'â‚¹ 7,525*\', \'2 Nights / 3 Days\'","\'Munnar, Thekkady\', \'â‚¹ 13,700*\', \'3 Nights / 4 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 12,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 19,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey\', \'â‚¹ 28,700*\', \'7 Nights / 8 Days\'"'}

# %%
#Training a model using these features
split_ratio = 0.8

def split_dataset(data, split_ratio):
    random.shuffle(data)
    data_length = len(data)
    train_split = int(data_length * split_ratio)
    return (data[:train_split]), (data[train_split:])

# %%
training_data, test_data = split_dataset(features_data, split_ratio)
training_data
# Out:
# [({'hotel': True, 'idukki': True}, 'Idukki-Hotels'),
#  ({'tell': True, 'hotel': True, 'kozhikod': True}, 'Kozhikode-Hotels'),
#  ({'packag': True, 'varkala': True}, 'Varkala-Package'),
#  ({'packag': True, 'kovalam': True}, 'Kovalam-Package'),
#  ({'varkala': True, 'pakag': True}, 'Varkala-Package'),
#  ({'great': True, 'talk': True}, 'Closing'),
#  ({'packag': True, 'thiruvananthapuram': True}, 'Trivandrum-Package'),
#  ({'hey': True, 'hi': True}, 'Greetings'),
#  ({'hey': True}, 'Greetings'),
#  ({'packag': True, 'varkala': True}, 'Varkala-Package'),
#  ({'hotel': True, 'thrissur': True}, 'Thrissur-Hotels'),
#  ({'hey': True, 'hello': True}, 'Greetings'),
#  ({'thrissoor': True, 'hotel': True}, 'Thrissur-Hotels'),
#  ({'kochi': True, 'pakag': True}, 'Kochi-Package'),
#  ({'packag': True, 'thekkadi': True}, 'Thekkady-Package'),
#  ({'hi': True}, 'Greetings'),
#  ({'hotel': True, 'vagamon': True}, 'Vagamon-Hotels'),
#  ({'packag': True, 'munnar': True}, 'Munnar-Package'),
#  ({'thank': True}, 'Closing'),
#  ({'good': True, 'morn': True}, 'Morning'),
#  ({'restaur': True, 'varkala': True}, 'Varkala-Restaurant'),
#  ({'packag': True, 'trivandrum': True}, 'Trivandrum-Package'),
#  ({'alleppey': True, 'restaur': True}, 'Alleppey-Restaurant'),
#  ({'hotel': True, 'periyar': True, 'nation': True, 'park': True},
#   'PeriyarNationalPark-Hotels'),
#  ({'place': True}, 'Best-Places'),
#  ({'tell': True, 'hotel': True, 'kovalam': True}, 'Kovalam-Hotels'),
#  ({'packag': True, 'idukki': True}, 'Idukki-Package'),
#  ({'calicut': True, 'pakag': True}, 'Kozhikode-Package'),
#  ({'restaur': True, 'thrissur': True}, 'Thrissur-Restaurant'),
#  ({'nilambur': True}, 'Nilambur-Package'),
#  ({'thiruvananthapuram': True, 'packag': True}, 'Trivandrum-Package'),
#  ({'restaur': True, 'vagamon': True}, 'Vagamon-Restaurant'),
#  ({'idukki': True, 'hotel': True}, 'Idukki-Hotels'),
#  ({'want': True, 'help': True}, 'No-Help'),
#  ({'alappuzha': True}, 'Alleppey-Package'),
#  ({'place': True, 'kerala': True}, 'Best-Places'),
#  ({'restaur': True}, 'Kozhikode-Restaurant'),
#  ({'packag': True, 'nilambur': True}, 'Nilambur-Package'),
#  ({'packag': True, 'kochi': True}, 'Kochi-Package'),
#  ({'packag': True, 'thekkadi': True}, 'Thekkady-Package'),
#  ({'thrissur': True, 'hotel': True}, 'Thrissur-Hotels'),
#  ({'kozhikod': True, 'restaur': True}, 'Kozhikode-Restaurant'),
#  ({'thrissur': True}, 'Thrissur-Package'),
#  ({'restaur': True, 'periyar': True, 'nation': True, 'park': True},
#   'PeriyarNationalPark-Restaurant'),
#  ({'thrissur': True, 'restur': True}, 'Thrissur-Restaurant'),
#  ({'alappuzha': True, 'packag': True}, 'Alleppey-Package'),
#  ({'good': True, 'night': True}, 'Goodbye'),
#  ({'periyar': True, 'nation': True, 'park': True, 'packag': True},
#   'PeriyarNationalPark-Package'),
#  ({'kozhikod': True, 'restaur': True}, 'Kozhikode-Restaurant'),
#  ({'restaur': True, 'kochi': True}, 'Kochi-Restaurant'),
#  ({'help': True}, 'No-Help'),
#  ({'place': True, 'kerala': True, 'visit': True}, 'Best-Places'),
#  ({'packag': True, 'trivandrum': True}, 'Trivandrum-Package'),
#  ({'packag': True, 'vagamon': True}, 'Vagamon-Package'),
#  ({'aleppi': True, 'restuar': True}, 'Alleppey-Restaurant'),
#  ({'thekkadi': True, 'pakag': True}, 'Thekkady-Package'),
#  ({'tell': True, 'hotel': True, 'thrissur': True}, 'Thrissur-Hotels'),
#  ({'need': True, 'help': True}, 'Help'),
#  ({'packag': True, 'idukki': True}, 'Idukki-Package'),
#  ({'packag': True, 'kochi': True}, 'Kochi-Package'),
#  ({'varkala': True, 'hotel': True}, 'Varkala-Hotels'),
#  ({'packag': True, 'vagamon': True}, 'Vagamon-Package'),
#  ({'packag': True, 'kochi': True}, 'Trivandrum-Package'),
#  ({'periyar': True, 'nation': True, 'park': True, 'restaur': True},
#   'PeriyarNationalPark-Restaurant'),
#  ({'restaur': True}, 'Kozhikode-Restaurant'),
#  ({'restaur': True, 'munnar': True}, 'Munnar-Restaurant'),
#  ({'munnar': True, 'restur': True}, 'Munnar-Restaurant'),
#  ({'periyar': True, 'nation': True, 'park': True, 'hotel': True},
#   'PeriyarNationalPark-Hotels'),
#  ({'tell': True, 'packag': True}, 'Select-Package'),
#  ({'thank': True, 'much': True}, 'Closing'),
#  ({'varkala': True, 'packag': True}, 'Varkala-Package'),
#  ({'pakag': True}, 'Select-Package'),
#  ({'help': True}, 'Help'),
#  ({'restaur': True, 'trivandrum': True}, 'Trivandrum-Restaurant'),
#  ({'today': True}, 'Opening'),
#  ({'packag': True, 'kumarakom': True}, 'Kumarakom-Package'),
#  ({'varkala': True, 'packag': True}, 'Varkala-Package'),
#  ({'packag': True}, 'Select-Package'),
#  ({'tell': True, 'hotel': True, 'kumarakom': True}, 'Vagamon-Hotels'),
#  ({'alleppey': True}, 'Alleppey-Package'),
#  ({'munnar': True, 'pakag': True}, 'Munnar-Package'),
#  ({'hotel': True, 'aleppey': True}, 'Alleppey-Hotels'),
#  ({'restaur': True, 'kovalam': True}, 'Kovalam-Restaurant'),
#  ({'packag': True, 'periyar': True, 'nation': True, 'park': True},
#   'PeriyarNationalPark-Package'),
#  ({'munnar': True, 'restuar': True}, 'Munnar-Restaurant'),
#  ({'thekkadi': True, 'packag': True}, 'Thekkady-Package'),
#  ({'restaur': True}, 'Kumarakom-Restaurant'),
#  ({'restaur': True, 'aleppey': True}, 'Alleppey-Restaurant'),
#  ({'restaur': True, 'trivandrum': True}, 'Trivandrum-Restaurant'),
#  ({'packag': True, 'thrissur': True}, 'Thrissur-Package'),
#  ({'wayanad': True}, 'Wayanad-Package'),
#  ({'nilambur': True, 'pakag': True}, 'Nilambur-Package'),
#  ({'restaur': True, 'vagamon': True}, 'Vagamon-Restaurant'),
#  ({'hi': True}, 'Greetings'),
#  ({'idukki': True, 'packag': True}, 'Idukki-Package'),
#  ({'kovalam': True, 'pakag': True}, 'Kovalam-Package'),
#  ({'restaur': True, 'munnar': True}, 'Munnar-Restaurant'),
#  ({'restaur': True, 'trivandrum': True}, 'Trivandrum-Restaurant'),
#  ({'hotel': True, 'trivandrum': True}, 'Trivandrum-Hotels'),
#  ({'munnar': True, 'packag': True}, 'Munnar-Package'),
#  ({'thiruvananthapuram': True, 'restaur': True}, 'Trivandrum-Restaurant'),
#  ({'kumarakom': True, 'pakag': True}, 'Kumarakom-Package'),
#  ({'packag': True, 'calicut': True}, 'Kozhikode-Package'),
#  ({'packag': True, 'alappuzha': True}, 'Alleppey-Package'),
#  ({'hi': True, 'hello': True}, 'Greetings'),
#  ({'vagamon': True}, 'Vagamon-Package'),
#  ({'restaur': True, 'wayanad': True}, 'Wayanad-Restaurant'),
#  ({'nilamboor': True, 'restaur': True}, 'Nilambur-Restaurant'),
#  ({'restaur': True, 'vagamon': True}, 'Vagamon-Restaurant'),
#  ({'hello': True, 'hi': True}, 'Greetings'),
#  ({'packag': True, 'varkala': True}, 'Varkala-Package'),
#  ({'restaur': True, 'alappuzha': True}, 'Alleppey-Restaurant'),
#  ({'tell': True, 'hotel': True, 'kochi': True}, 'Kochi-Hotels'),
#  ({'packag': True, 'kovalam': True}, 'Kovalam-Package'),
#  ({'aleppey': True, 'hotel': True}, 'Alleppey-Hotels'),
#  ({'hotel': True, 'kumarakom': True}, 'Kumarakom-Hotels'),
#  ({'place': True, 'india': True}, 'India-Places'),
#  ({'thrissur': True, 'packag': True}, 'Thrissur-Package'),
#  ({'restaur': True, 'thrissur': True}, 'Thrissur-Restaurant'),
#  ({'hey': True}, 'Greetings'),
#  ({'alleppi': True, 'restur': True}, 'Alleppey-Restaurant'),
#  ({'idukki': True, 'pakag': True}, 'Idukki-Package'),
#  ({'packag': True, 'wayanad': True}, 'Wayanad-Package'),
#  ({'vagamon': True, 'hotel': True}, 'Vagamon-Hotels'),
#  ({'packag': True, 'wayanad': True}, 'Wayanad-Package'),
#  ({'restaur': True, 'nilambur': True}, 'Nilambur-Restaurant'),
#  ({'trivandrum': True}, 'Trivandrum-Package'),
#  ({'kochi': True, 'packag': True}, 'Kochi-Package'),
#  ({'nilambur': True, 'restaur': True}, 'Nilambur-Restaurant'),
#  ({'wayanad': True, 'pakag': True}, 'Wayanad-Package'),
#  ({'tell': True, 'hotel': True, 'wayanad': True}, 'Wayanad-Hotels'),
#  ({'periyar': True, 'pakag': True}, 'PeriyarNationalPark-Package'),
#  ({'good': True, 'afternoon': True}, 'Afternoon'),
#  ({'packag': True, 'munnar': True}, 'Munnar-Package'),
#  ({'great': True}, 'Closing'),
#  ({'kozhikod': True, 'packag': True}, 'Kozhikode-Package'),
#  ({'hotel': True, 'varkala': True}, 'Varkala-Hotels'),
#  ({'packag': True, 'nilambur': True}, 'Nilambur-Package'),
#  ({'kumarakom': True, 'hotel': True}, 'Kumarakom-Hotels'),
#  ({'packag': True, 'alleppey': True}, 'Alleppey-Package'),
#  ({'kochi': True, 'restaur': True}, 'Kochi-Restaurant'),
#  ({'restaur': True, 'varkala': True}, 'Varkala-Restaurant'),
#  ({'calicut': True, 'packag': True}, 'Kozhikode-Package'),
#  ({'thiruvananthapuram': True, 'hotel': True}, 'Trivandrum-Hotels'),
#  ({'kochi': True, 'packag': True}, 'Kochi-Package'),
#  ({'packag': True, 'calicut': True}, 'Kozhikode-Package'),
#  ({'packag': True, 'varkala': True}, 'Varkala-Package'),
#  ({'kovalam': True, 'restaur': True}, 'Kovalam-Restaurant'),
#  ({'packag': True, 'vagamon': True}, 'Vagamon-Package'),
#  ({'hello': True}, 'Greetings'),
#  ({'restaur': True, 'vagamon': True}, 'Vagamon-Restaurant'),
#  ({'alappuzha': True, 'restaur': True}, 'Alleppey-Restaurant'),
#  ({'munnar': True, 'hotel': True}, 'Munnar-Hotels'),
#  ({'trivandrum': True, 'packag': True}, 'Trivandrum-Package'),
#  ({'wayanad': True, 'restur': True}, 'Wayanad-Restaurant'),
#  ({'hotel': True, 'kovalam': True}, 'Kovalam-Hotels'),
#  ({'nilambur': True, 'packag': True}, 'Nilambur-Package'),
#  ({'packag': True, 'munnar': True}, 'Munnar-Package'),
#  ({'restaur': True}, 'Kochi-Restaurant'),
#  ({'restaur': True, 'alleppey': True}, 'Alleppey-Restaurant'),
#  ({'restaur': True, 'wayanad': True}, 'Wayanad-Restaurant'),
#  ({'periyar': True, 'nation': True, 'park': True},
#   'PeriyarNationalPark-Hotels'),
#  ({'varkala': True}, 'Varkala-Package'),
#  ({'hotel': True, 'aalappuzha': True}, 'Alleppey-Hotels'),
#  ({'hotel': True, 'alleppey': True}, 'Alleppey-Hotels'),
#  ({'thrissoor': True, 'restur': True}, 'Thrissur-Restaurant'),
#  ({'hotel': True, 'alleppey': True}, 'Alleppey-Hotels'),
#  ({'varkala': True, 'restur': True}, 'Varkala-Restaurant'),
#  ({'hotel': True, 'munnar': True}, 'Munnar-Hotels'),
#  ({'kochi': True}, 'Kochi-Package'),
#  ({'wayanad': True, 'restaur': True}, 'Wayanad-Restaurant'),
#  ({'locat': True}, 'Best-Places'),
#  ({'kozhikod': True, 'hotel': True}, 'Kozhikode-Hotels'),
#  ({'thrissur': True, 'hotel': True}, 'Thrissur-Hotels'),
#  ({'restaur': True, 'allepi': True}, 'Alleppey-Restaurant'),
#  ({'want': True, 'help': True}, 'Help'),
#  ({'kozhikod': True, 'packag': True}, 'Kozhikode-Package'),
#  ({'hotel': True, 'munnar': True}, 'Munnar-Hotels'),
#  ({'packag': True, 'nilambur': True}, 'Nilambur-Package'),
#  ({'thrissur': True, 'restaur': True}, 'Thrissur-Restaurant'),
#  ({'aalappuzha': True, 'packag': True}, 'Alleppey-Package'),
#  ({'packag': True, 'periyar': True, 'nation': True, 'park': True},
#   'PeriyarNationalPark-Package'),
#  ({'ernakulam': True, 'packag': True}, 'Kochi-Package'),
#  ({'varkala': True, 'pakag': True}, 'Varkala-Package'),
#  ({'hotel': True, 'thrissur': True}, 'Thrissur-Hotels'),
#  ({'hotel': True, 'kovalam': True}, 'Kovalam-Hotels'),
#  ({'allepi': True, 'packag': True}, 'Alleppey-Package'),
#  ({'kovalam': True, 'packag': True}, 'Kovalam-Package'),
#  ({'good': True, 'even': True}, 'Evening'),
#  ({'restaur': True, 'nilambur': True}, 'Nilambur-Restaurant'),
#  ({'idukki': True}, 'Idukki-Package'),
#  ({'restaur': True, 'aleppey': True}, 'Alleppey-Restaurant'),
#  ({'place': True, 'india': True}, 'India-Places'),
#  ({'periyar': True, 'nation': True, 'park': True, 'pakag': True},
#   'PeriyarNationalPark-Package'),
#  ({'thank': True}, 'Closing'),
#  ({'place': True}, 'Best-Places'),
#  ({'restaur': True, 'thrissur': True}, 'Thrissur-Restaurant'),
#  ({'tell': True, 'hotel': True, 'alleppey': True}, 'Alleppey-Hotels'),
#  ({'restaur': True, 'alleppey': True}, 'Alleppey-Restaurant'),
#  ({'tell': True, 'hotel': True, 'munnar': True}, 'Munnar-Hotels'),
#  ({'restaur': True}, 'Kozhikode-Restaurant'),
#  ({'packag': True, 'trivandrum': True}, 'Trivandrum-Package'),
#  ({'hotel': True, 'periyar': True, 'nation': True, 'park': True},
#   'PeriyarNationalPark-Hotels'),
#  ({'packag': True, 'kozhikod': True}, 'Kozhikode-Package'),
#  ({'restaur': True, 'periyar': True, 'nation': True, 'park': True},
#   'PeriyarNationalPark-Restaurant'),
#  ({'calicut': True, 'restur': True}, 'Kozhikode-Restaurant'),
#  ({'packag': True, 'thekkadi': True}, 'Thekkady-Package'),
#  ({'hotel': True, 'nilambur': True}, 'Nilambur-Hotels'),
#  ({'hotel': True, 'vagamon': True}, 'Vagamon-Hotels'),
#  ({'restaur': True}, 'Kovalam-Restaurant'),
#  ({'hotel': True, 'kozhikod': True}, 'Kozhikode-Hotels'),
#  ({'packag': True, 'nilambur': True}, 'Nilambur-Package'),
#  ({'kochi': True, 'restaur': True}, 'Kochi-Restaurant'),
#  ({'kumarakom': True, 'packag': True}, 'Kumarakom-Package'),
#  ({'ernakulam': True, 'hotel': True}, 'Kochi-Hotels'),
#  ({'kozhikod': True}, 'Kozhikode-Package'),
#  ({'thekkadi': True}, 'Thekkady-Package'),
#  ({'restaur': True, 'wayanad': True}, 'Wayanad-Restaurant'),
#  ({'hotel': True, 'wayanad': True}, 'Wayanad-Hotels'),
#  ({'thekkadi': True, 'packag': True}, 'Thekkady-Package'),
#  ({'restaur': True, 'idukki': True}, 'Idukki-Restaurant'),
#  ({'idukki': True, 'packag': True}, 'Idukki-Package'),
#  ({'hotel': True, 'calicut': True}, 'Kozhikode-Hotels'),
#  ({'restaur': True, 'idukki': True}, 'Idukki-Restaurant'),
#  ({'kozhikod': True}, 'Kozhikode-Package'),
#  ({'wayanad': True, 'hotel': True}, 'Wayanad-Hotels'),
#  ({'restaur': True, 'kumarakom': True}, 'Kumarakom-Restaurant'),
#  ({'restaur': True, 'munnar': True}, 'Munnar-Restaurant'),
#  ({'kovalam': True}, 'Kovalam-Package'),
#  ({'munnar': True, 'packag': True}, 'Munnar-Package'),
#  ({'packag': True, 'idukki': True}, 'Idukki-Package'),
#  ({'packag': True, 'alleppey': True}, 'Alleppey-Package'),
#  ({'trivandrum': True, 'packag': True}, 'Trivandrum-Package'),
#  ({'thrissur': True, 'pakag': True}, 'Thrissur-Package'),
#  ({'munnar': True, 'restaur': True}, 'Munnar-Restaurant'),
#  ({'restaur': True, 'allepey': True}, 'Alleppey-Restaurant'),
#  ({'restaur': True}, 'Kochi-Restaurant'),
#  ({'trivandrum': True, 'restaur': True}, 'Trivandrum-Restaurant'),
#  ({'kumarakom': True}, 'Kumarakom-Package'),
#  ({'varkala': True, 'restuar': True}, 'Varkala-Restaurant'),
#  ({'wayanad': True, 'restuar': True}, 'Wayanad-Restaurant'),
#  ({'thiruvananthapuram': True}, 'Trivandrum-Restaurant'),
#  ({'varkala': True, 'restaur': True}, 'Varkala-Restaurant'),
#  ({'thrissur': True, 'packag': True}, 'Thrissur-Package'),
#  ({'nilamboor': True}, 'Nilambur-Package'),
#  ({'wayanad': True, 'packag': True}, 'Wayanad-Package'),
#  ({'kochi': True, 'hotel': True}, 'Kochi-Hotels'),
#  ({'munnar': True}, 'Munnar-Package'),
#  ({'restaur': True, 'alappuzha': True}, 'Alleppey-Restaurant'),
#  ({'periyar': True, 'packag': True}, 'PeriyarNationalPark-Package'),
#  ({'calicut': True, 'restaur': True}, 'Kozhikode-Restaurant'),
#  ({'nilambur': True, 'restaur': True}, 'Nilambur-Restaurant'),
#  ({'alleppey': True, 'hotel': True}, 'Alleppey-Hotels'),
#  ({'kovalam': True, 'hotel': True}, 'Kovalam-Hotels'),
#  ({'periyar': True, 'nation': True, 'park': True, 'packag': True},
#   'PeriyarNationalPark-Package'),
#  ({'hotel': True, 'wayanad': True}, 'Wayanad-Hotels'),
#  ({'periyar': True, 'hotel': True}, 'PeriyarNationalPark-Hotels'),
#  ({'restaur': True, 'idukki': True}, 'Idukki-Restaurant'),
#  ({'nilambur': True, 'packag': True}, 'Idukki-Package'),
#  ({'wayanad': True, 'packag': True}, 'Wayanad-Package'),
#  ({'idukki': True, 'restaur': True}, 'Idukki-Restaurant'),
#  ({'restaur': True, 'nilambur': True}, 'Nilambur-Restaurant'),
#  ({'tell': True, 'kozhikod': True, 'packag': True}, 'Kozhikode-Package'),
#  ({'thank': True, 'help': True}, 'Closing'),
#  ({'want': True, 'assist': True}, 'No-Help'),
#  ({'nilambur': True, 'pakag': True}, 'Nilambur-Package'),
#  ({'packag': True, 'alleppey': True}, 'Alleppey-Package'),
#  ({'thrissoor': True, 'restaur': True}, 'Thrissur-Restaurant'),
#  ({'place': True, 'visit': True, 'kerala': True}, 'Best-Places'),
#  ({'restaur': True, 'periyar': True, 'nation': True, 'park': True},
#   'PeriyarNationalPark-Restaurant'),
#  ({'restur': True, 'alappuzha': True}, 'Alleppey-Restaurant'),
#  ({'calicut': True, 'hotel': True}, 'Kozhikode-Hotels'),
#  ({'restaur': True, 'varkala': True}, 'Varkala-Restaurant'),
#  ({'restaur': True}, 'Kozhikode-Restaurant'),
#  ({'restaur': True, 'wayanad': True}, 'Wayanad-Restaurant'),
#  ({'vagamon': True, 'restaur': True}, 'Vagamon-Restaurant'),
#  ({'tell': True, 'hotel': True, 'trivandrum': True}, 'Trivandrum-Hotels'),
#  ({'packag': True}, 'Select-Package'),
#  ({'restaur': True, 'kumarakom': True}, 'Kumarakom-Restaurant'),
#  ({'restaur': True, 'alappuzha': True}, 'Alleppey-Restaurant'),
#  ({'restaur': True, 'thrissur': True}, 'Thrissur-Restaurant'),
#  ({'periyar': True, 'nation': True, 'park': True, 'packag': True},
#   'PeriyarNationalPark-Package'),
#  ({'hi': True}, 'Greetings'),
#  ({'hotel': True, 'alappuzha': True}, 'Alleppey-Hotels'),
#  ({'hotel': True, 'alappuzha': True}, 'Alleppey-Hotels')]

# %%
#save the data
np.save('training_data', training_data)
np.save('test_data', test_data)

# %%
#classification using Decision tree
training_data = np.load('training_data.npy', allow_pickle=True)
test_data = np.load('test_data.npy', allow_pickle=True)

# %%
def train_using_decision_tree(training_data, test_data):
    classifier =nltk.classify.DecisionTreeClassifier.train(training_data, entropy_cutoff=0.6, support_cutoff=6)
    classifier_name = type(classifier).__name__
    training_set_accuracy = nltk.classify.accuracy(classifier, training_data)
    print('training set accuracy:', training_set_accuracy)
    test_set_accuracy = nltk.classify.accuracy(classifier, test_data)
    print('test set accuracy :', test_set_accuracy)
    return classifier, classifier_name, test_set_accuracy, training_set_accuracy

# %%
dtclassifier, classifer_name, test_set_accuracy, training_set_accuracy = train_using_decision_tree(training_data, test_data)
# Out:
# training set accuracy: 0.9228070175438596
# test set accuracy : 0.8055555555555556

# %%
def train_using_naiveBayes(training_data, test_data):
    classifier =nltk.classify.NaiveBayesClassifier.train(training_data)
    classifier_name = type(classifier).__name__
    training_set_accuracy = nltk.classify.accuracy(classifier, training_data)
    print('training set accuracy:', training_set_accuracy)
    test_set_accuracy = nltk.classify.accuracy(classifier, test_data)
    print('test set accuracy :', test_set_accuracy)
    return classifier, classifier_name, test_set_accuracy, training_set_accuracy

# %%
classifier, classifer_name, test_set_accuracy, training_set_accuracy = train_using_naiveBayes(training_data, test_data)
# Out:
# training set accuracy: 0.9228070175438596
# test set accuracy : 0.8055555555555556

# %%
print(len(classifier.most_informative_features()))
# Out:
# 100

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#                 nilambur = None           Allepp : Nilamb =      6.4 : 1.0
#                   packag = None           Allepp : Trivan =      6.4 : 1.0
#                   idukki = None           Allepp : Idukki =      5.8 : 1.0
#                  restaur = None           Greeti : Kozhik =      5.7 : 1.0
#                    kochi = True           Kochi- : Trivan =      5.4 : 1.0
#                    kochi = None           Allepp : Kochi- =      5.2 : 1.0
#                 nilambur = True           Nilamb : Idukki =      5.1 : 1.0
#                    place = None           Allepp : Best-P =      4.5 : 1.0
#                 thrissur = None           Allepp : Thriss =      4.5 : 1.0
#                     help = True             Help : Closin =      4.1 : 1.0

# %%
classifier.classify(({'mani': True, 'option': True, 'leav': True}))
# Out:
# 'Alleppey-Restaurant'

# %%
extract_features('hello')
# Out:
# ['hello']

# %%
word_feats(extract_features('hello'))
# Out:
# {'hello': True}

# %%
input_sentence = 'how many balanced leaves do I have?'
classifier.classify(word_feats(extract_features(input_sentence)))
# Out:
# 'Alleppey-Restaurant'

# %%
def reply(input_sentence):
    category = dtclassifier.classify(word_feats(extract_features(input_sentence)))
    
    return answers[category]

# %%
def reply(input_sentence):
    category = dtclassifier.classify(word_feats(extract_features(input_sentence)))
    if category == 'Best-Places':
        places = answers[category].split(',')
        return ', '.join(random.sample(places, 5))
    if category == 'Munnar-package':
        # Split the string into packages
        packages = answers[category].split("', '")
        # Select 4 random packages
        selected_packages = random.sample(packages, min(4, len(packages)))
        # Join the selected packages with newline and return
        return '\n'.join(selected_packages)
    return answers[category]

# %%
reply('hello')
# Out:
# 'Hello. I am ABHIbot. I will serve your leave enquiries.'

# %%
reply('kerala places')
# Out:
# 'Periyar National Park, Thekkady, Bekal, Nilambur, Nelliyampathy'

# %%
reply('places in kerala')
# Out:
# 'Poovar, Vagamon, Kalpetta, Kasaragod, Ponmudi'

# %%
reply('Kerala munnar package')
# Out:
# "The packages for munnar are,'Munnar, Alleppey, Kovalam', 'â‚¹ 18,900*', '4 Nights / 5 Days', 'Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Kochi, Munnar, Alleppey', 'â‚¹ 14,300*', '3 Nights / 4 Days','Munnar, Alleppey', 'â‚¹ 12,900*', '3 Nights / 4 Days',Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey', 'â‚¹ 28,700*', '7 Nights / 8 Days'."

# %%
reply('munnar')
# Out:
# "The packages for munnar are,'Munnar, Alleppey, Kovalam', 'â‚¹ 18,900*', '4 Nights / 5 Days', 'Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Kochi, Munnar, Alleppey', 'â‚¹ 14,300*', '3 Nights / 4 Days','Munnar, Alleppey', 'â‚¹ 12,900*', '3 Nights / 4 Days',Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey', 'â‚¹ 28,700*', '7 Nights / 8 Days'."

# %%
reply('packages for munnar')
# Out:
# "The packages for munnar are,'Munnar, Alleppey, Kovalam', 'â‚¹ 18,900*', '4 Nights / 5 Days', 'Munnar, Thekkady, Alleppey', 'â‚¹ 19,000*', '4 Nights / 5 Days','Kochi, Munnar, Alleppey', 'â‚¹ 14,300*', '3 Nights / 4 Days','Munnar, Alleppey', 'â‚¹ 12,900*', '3 Nights / 4 Days',Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey', 'â‚¹ 28,700*', '7 Nights / 8 Days'."

# %%
reply('Idukki package')
# Out:
# 'The packages for Nilambur are,"\'Nilambur, Kozhikode\', \'â‚¹ 7,000*\', \'2 Nights / 3 Days\'","\'Ooty, Nilambur, Palakkad\', \'â‚¹ 9,000*\', \'3 Nights / 4 Days\'","\'Ooty, Nilambur\', \'â‚¹ 10,000*\', \'3 Nights / 4 Days\'","\'Kozhikode, Nilambur, Ooty, Mudumalai, Bandipur, Nagarhole, Kalpetta, Wayanad\', \'â‚¹ 18,500*\', \'7 Nights / 8 Days\'","\'Kannur, Thalassery, Kozhikode, Nilambur, Kalpetta, Wayanad\', \'â‚¹ 16,000*\', \'6 Nights / 7 Days\'"'

# %%
reply('Nilambur')
# Out:
# 'The packages for Nilambur are,"\'Nilambur, Kozhikode\', \'â‚¹ 7,000*\', \'2 Nights / 3 Days\'","\'Ooty, Nilambur, Palakkad\', \'â‚¹ 9,000*\', \'3 Nights / 4 Days\'","\'Ooty, Nilambur\', \'â‚¹ 10,000*\', \'3 Nights / 4 Days\'","\'Kozhikode, Nilambur, Ooty, Mudumalai, Bandipur, Nagarhole, Kalpetta, Wayanad\', \'â‚¹ 18,500*\', \'7 Nights / 8 Days\'","\'Kannur, Thalassery, Kozhikode, Nilambur, Kalpetta, Wayanad\', \'â‚¹ 16,000*\', \'6 Nights / 7 Days\'"'

# %%
reply('package for kochi')
# Out:
# "The packages for Kochi are,'Kochi, Munnar', 'â‚¹ 10,000*', '3 Nights / 4 Days','Kochi, Munnar, Alleppey', 'â‚¹ 21,000*', '5 Nights / 6 Days','Kochi, Munnar, Kumarakom', 'â‚¹ 17,350*', '4 Nights / 5 Days','Kochi, Munnar, Thekkady, Kumarakom', 'â‚¹ 27,950*', '6 Nights / 7 Days','Kochi, Munnar, Thekkady, Kumarakom, Alleppey, Kovalam, Trivandrum', 'â‚¹ 34,890*', '8 Nights / 9 Days'"

# %%
reply('periyar national park')
# Out:
# 'The packages for periyar national park are,"\'Thekkady\', \'â‚¹ 7,525*\', \'2 Nights / 3 Days\'","\'Munnar, Thekkady\', \'â‚¹ 13,700*\', \'3 Nights / 4 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 12,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Alleppey\', \'â‚¹ 19,000*\', \'4 Nights / 5 Days\'","\'Munnar, Thekkady, Kovalam, Kanyakumari, Alleppey\', \'â‚¹ 28,700*\', \'7 Nights / 8 Days\'"'
